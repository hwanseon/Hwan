# %%
from sklearn.datasets import make_moons
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
from sklearn.impute import KNNImputer
import pandas as pd
import matplotlib.pyplot as plt
import koreanize_matplotlib
from tabulate import tabulate 
import glob

from sklearn.preprocessing import LabelEncoder
import seaborn as sns

from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.metrics import mean_squared_error, r2_score
import joblib

# %%
NABIS = pd.read_csv("./진짜 진짜 진짜로 전처리 완료된 대회 분석 데이터.csv")
NABIS = pd.DataFrame(NABIS)
NABIS
# Out:
#       Unnamed: 0    연도    의료수가   가중치  지역 소아과 수        최종수가  강원특별자치도_건강보험  \
# 0              0  2019  258854  74.9       864  19388164.6       1491120
# 1              1  2019  258854  83.4       864  21588423.6       1491120
# 2              2  2019  258854  74.9     10940  19388164.6       1491120
# 3              3  2019  258854  83.4     10940  21588423.6       1491120
# 4              4  2019  258854  74.9      8032  19388164.6       1491120
# ...          ...   ...     ...   ...       ...         ...           ...
# 1787        1787  2022  617545  78.4      8032  48415528.0       1503671
# 1788        1788  2022  617545  78.4       996  48415528.0       1503671
# 1789        1789  2022  617545  90.2       996  55702559.0       1503671
# 1790        1790  2022  617545  78.4       816  48415528.0       1503671
# 1791        1791  2022  617545  90.2       816  55702559.0       1503671
#
#       강원특별자치도_소아과 병원 수  강원특별자치도_소아과 의료인력 수  강원특별자치도_천명당 소아과 수  ...  \
# 0                  864                 527           0.142105  ...
# 1                  864                 527           0.142105  ...
# 2                  864                 527           0.142105  ...
# 3                  864                 527           0.142105  ...
# 4                  864                 527           0.142105  ...
# ...                ...                 ...                ...  ...
# 1787               904                 618           0.148003  ...
# 1788               904                 618           0.148003  ...
# 1789               904                 618           0.148003  ...
# 1790               904                 618           0.148003  ...
# 1791               904                 618           0.148003  ...
#
#       전북특별자치도_소아과 병원 수_표준화  전북특별자치도_소아과 의료인력 수_표준화  전라남도_소아과 병원 수_표준화  \
# 0                 1.532478               -0.463988           1.310556
# 1                 1.532478               -0.463988           1.310556
# 2                 1.532478               -0.463988           1.310556
# 3                 1.532478               -0.463988           1.310556
# 4                 1.532478               -0.463988           1.310556
# ...                    ...                     ...                ...
# 1787             -0.998219                1.716757          -0.087370
# 1788             -0.998219                1.716757          -0.087370
# 1789             -0.998219                1.716757          -0.087370
# 1790             -0.998219                1.716757          -0.087370
# 1791             -0.998219                1.716757          -0.087370
#
#       전라남도_소아과 의료인력 수_표준화  경상북도_소아과 병원 수_표준화  경상북도_소아과 의료인력 수_표준화  \
# 0                0.110959           0.848528             1.163333
# 1                0.110959           0.848528             1.163333
# 2                0.110959           0.848528             1.163333
# 3                0.110959           0.848528             1.163333
# 4                0.110959           0.848528             1.163333
# ...                   ...                ...                  ...
# 1787            -0.776713          -0.848528            -1.398134
# 1788            -0.776713          -0.848528            -1.398134
# 1789            -0.776713          -0.848528            -1.398134
# 1790            -0.776713          -0.848528            -1.398134
# 1791            -0.776713          -0.848528            -1.398134
#
#       경상남도_소아과 병원 수_표준화  경상남도_소아과 의료인력 수_표준화  제주특별자치도_소아과 병원 수_표준화  \
# 0              1.427416            -1.091442             -1.647064
# 1              1.427416            -1.091442             -1.647064
# 2              1.427416            -1.091442             -1.647064
# 3              1.427416            -1.091442             -1.647064
# 4              1.427416            -1.091442             -1.647064
# ...                 ...                  ...                   ...
# 1787          -0.965205             1.570042              0.930949
# 1788          -0.965205             1.570042              0.930949
# 1789          -0.965205             1.570042              0.930949
# 1790          -0.965205             1.570042              0.930949
# 1791          -0.965205             1.570042              0.930949
#
#       제주특별자치도_소아과 의료인력 수_표준화
# 0                  -1.598822
# 1                  -1.598822
# 2                  -1.598822
# 3                  -1.598822
# 4                  -1.598822
# ...                      ...
# 1787                1.157767
# 1788                1.157767
# 1789                1.157767
# 1790                1.157767
# 1791                1.157767
#
# [1792 rows x 121 columns]

# %%
from sklearn.cluster import KMeans

features = NABIS[['진료과목_인코딩', '지역_인코딩', '의료기관_인코딩', '최종수가_표준화', '지역 소아과 수', 
    '경상북도_건강보험', '경상북도_소아과 병원 수_표준화', "경상북도_소아과 의료인력 수_표준화", "경상북도_천명당 소아과 수"]]

# n_clusters: 군집 개수를 설정 
n_clusters = 40
kmeans = KMeans(n_clusters=n_clusters, random_state=43)

NABIS['K-MEAN 군집'] = kmeans.fit_predict(features)

KGoonjib = './K-MEAN 경상북도 군집화 결과2.xlsx'
NABIS.to_excel(KGoonjib, index=False)

NABIS['K-MEAN 군집'].value_counts()
# Out:
# K-MEAN 군집
# 4     168
# 5     168
# 6     168
# 3     168
# 29     56
# 30     56
# 18     56
# 7      56
# 1      28
# 37     28
# 19     28
# 0      28
# 23     28
# 24     28
# 12     28
# 38     28
# 9      28
# 21     28
# 2      28
# 32     28
# 26     28
# 34     28
# 10     28
# 8      28
# 28     28
# 33     28
# 22     28
# 13     28
# 20     28
# 27     28
# 36     28
# 14     28
# 11     28
# 35     28
# 16     28
# 15     28
# 17     28
# 25     28
# 39     28
# 31     28
# Name: count, dtype: int64

# %%
# Elbow 방법으로 SSE(군집내 제곱합)을 계산하여 최적의 군집 수 찾기
sse = []  
k_range = range(1, 40)  

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=43)
    kmeans.fit(features)
    sse.append(kmeans.inertia_)  

plt.figure(figsize=(10, 6))
plt.plot(k_range, sse, marker='o')
plt.xlabel('K')
plt.ylabel('SSE')
plt.title('Elbow의 최적의 군집 수')
plt.xticks(k_range)
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import silhouette_score

# 실루엣 계수로 최적의 군집 수 찾기
silhouette_scores = []
k_range = range(2, 50)  

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=43)
    cluster_labels = kmeans.fit_predict(features)
    silhouette_avg = silhouette_score(features, cluster_labels)
    silhouette_scores.append(silhouette_avg)

plt.figure(figsize=(10, 6))
plt.plot(k_range, silhouette_scores, marker='o')
plt.xlabel('k')
plt.ylabel('실루엣 스코어')
plt.title('Silhouette Score의 최적의 군집 수')
plt.xticks(k_range)
plt.grid(True)
plt.show()

# %%
# k-mean 군집화 분석 

Kcluster_counts = NABIS['K-MEAN 군집'].value_counts()
print("\n군집별 데이터 수:\n", Kcluster_counts)

Kcluster_means = NABIS.groupby('K-MEAN 군집').mean()
print("\n군집별 평균값:\n", Kcluster_means)

plt.figure(figsize=(10, 6))
sns.boxplot(x='K-MEAN 군집', y='최종수가_표준화', data=NABIS)
plt.title('군집별 최종수가_표준화 분포')
plt.xlabel('군집')
plt.ylabel('최종수가_표준화')
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x='K-MEAN 군집', y='지역 소아과 수', data=NABIS)
plt.title('군집별 지역 소아과 수 분포')
plt.xlabel('군집')
plt.ylabel('지역 소아과 수')
plt.grid(True)
plt.show()
# Out:
# 군집별 데이터 수:
#  K-MEAN 군집
# 4     168
# 5     168
# 6     168
# 3     168
# 29     56
# 30     56
# 18     56
# 7      56
# 1      28
# 37     28
# 19     28
# 0      28
# 23     28
# 24     28
# 12     28
# 38     28
# 9      28
# 21     28
# 2      28
# 32     28
# 26     28
원특별자치도_소아과 병원 수  강원특별자치도_소아과 의료인력 수  \
# K-MEAN 군집
# 0          1.205247e+08     1499980.0             876.0               580.0
# 1          1.173609e+08     1491120.0             864.0               527.0
# 2          1.231529e+08     1503671.0             904.0               618.0
# 3          1.127416e+08     1494407.0             904.0               537.0
# 4          1.121094e+08     1491120.0             864.0               527.0
# 5          1.159702e+08     1503671.0             904.0               618.0
# 6          1.142512e+08     1499980.0             876.0               580.0
# 7          1.185983e+08     1494407.0             904.0               537.0
# 8          1.205247e+08     1499980.0             876.0               580.0
# 9          1.231529e+08     1503671.0             904.0               618.0
# 10         1.205247e+08     1499980.0             876.0               580.0
# 11         1.173609e+08     1491120.0             864.0               527.0
# 12         1.231529e+08     1503671.0             904.0               618.0
# 13         1.173609e+08     1491120.0             864.0               527.0
# 14         1.185983e+08     1494407.0             904.0               537.0
# 15         1.185983e+08     1494407.0             904.0               537.0
# 16         1.185983e+08     1494407.0             904.0               537.0
# 17         1.185983e+08     1494407.0             904.0               537.0
# 18         1.231529e+08     1503671.0             904.0               618.0
# 19         1.205247e+08     1499980.0             876.0               580.0
# 20         1.173609e+08     1491120.0             864.0               527.0
# 21         1.231529e+08     1503671.0             904.0               618.0
# 22         1.173609e+08     1491120.0             864.0               527.0
# 23         1.205247e+08     1499980.0             876.0               580.0
# 24         1.205247e+08     1499980.0             876.0               580.0
# 25         1.185983e+08     1494407.0             904.0               537.0
# 26         1.231529e+08     1503671.0             904.0               618.0
# 27         1.173609e+08     1491120.0             864.0               527.0
# 28         1.185983e+08     1494407.0             904.0               537.0
# 29         1.205247e+08     1499980.0             876.0               580.0
# 30         1.173609e+08     1491120.0             864.0               527.0
# 31         1.231529e+08     1503671.0             904.0               618.0
# 32         1.231529e+08     1503671.0             904.0               618.0
# 33         1.173609e+08     1491120.0             864.0               527.0
# 34         1.205247e+08     1499980.0             876.0               580.0
# 35         1.185983e+08     1494407.0             904.0               537.0
# 36         1.173609e+08     1491120.0             864.0               527.0
# 37         1.205247e+08     1499980.0             876.0               580.0
# 38         1.231529e+08     1503671.0             904.0               618.0
# 39         1.185983e+08     1494407.0             904.0               537.0
#
#            강원특별자치도_천명당 소아과 수  ...  전북특별자치도_소아과 병원 수_표준화  \
# K-MEAN 군집                     ...
# 0                   0.144079  ...             -0.773269
# 1                   0.142105  ...              1.532478
# 2                   0.148003  ...             -0.998219
# 3                   0.148782  ...              0.239010
# 4                   0.142105  ...              1.532478
# 5                   0.148003  ...             -0.998219
# 6                   0.144079  ...             -0.773269
# 7                   0.148782  ...              0.239010
# 8                   0.144079  ...             -0.773269
# 9                   0.148003  ...             -0.998219
# 10                  0.144079  ...             -0.773269
# 11                  0.142105  ...              1.532478
# 12                  0.148003  ...             -0.998219
# 13                  0.142105  ...              1.532478
# 14                  0.148782  ...              0.239010
# 15                  0.148782  ...              0.239010
# 16                  0.148782  ...              0.239010
# 17                  0.148782  ...              0.239010
# 33                   -1.091442             -1.647064               -1.598822
# 34                    0.099222              0.644503                0.275659
# 35                   -0.577822              0.071611                0.165395
# 36                   -1.091442             -1.647064               -1.598822
# 37                    0.099222              0.644503                0.275659
# 38                    1.570042              0.930949                1.157767
# 39                   -0.577822              0.071611                0.165395
#
# [40 rows x 121 columns]

# %%
# PCA
from sklearn.decomposition import PCA
NABIS1 = NABIS.copy()

# 2차원 축소
pca = PCA(n_components=2)
pca_result = pca.fit_transform(features)

NABIS1['PCA1'] = pca_result[:, 0]
NABIS1['PCA2'] = pca_result[:, 1]

plt.figure(figsize=(12, 8))
sns.scatterplot(x='PCA1', y='PCA2', hue='K-MEAN 군집', palette='Set1', data=NABIS1, s=50, alpha=0.7, edgecolor='k')
plt.title('주성분 분석')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.legend(title='Cluster')
plt.grid(True)
plt.show()

# %%
NABIS.columns
# Out:
# Index(['Unnamed: 0', '연도', '의료수가', '가중치', '지역 소아과 수', '최종수가', '강원특별자치도_건강보험',
#        '강원특별자치도_소아과 병원 수', '강원특별자치도_소아과 의료인력 수', '강원특별자치도_천명당 소아과 수',
#        ...
#        '전북특별자치도_소아과 의료인력 수_표준화', '전라남도_소아과 병원 수_표준화', '전라남도_소아과 의료인력 수_표준화',
#        '경상북도_소아과 병원 수_표준화', '경상북도_소아과 의료인력 수_표준화', '경상남도_소아과 병원 수_표준화',
#        '경상남도_소아과 의료인력 수_표준화', '제주특별자치도_소아과 병원 수_표준화', '제주특별자치도_소아과 의료인력 수_표준화',
#        'K-MEAN 군집'],
#       dtype='object', length=122)

# %%
X = NABIS[['진료과목_인코딩', '지역_인코딩', '의료기관_인코딩', '최종수가_표준화', 'K-MEAN 군집', '경상북도_건강보험', '의료수가_표준화', "경상북도_소아과 병원 수_표준화",
           "경상북도_소아과 의료인력 수_표준화"]]
y = NABIS['경상북도_천명당 소아과 수']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43)

xgb_model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=170, learning_rate=0.01, max_depth=7, random_state=43)

# 모델 학습
xgb_model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_test, y_test)], verbose=True)

evals_result = xgb_model.evals_result()
train_loss = evals_result['validation_0']['rmse']
test_loss = evals_result['validation_1']['rmse']

train_r2_scores = []
test_r2_scores = []

for i in range(len(train_loss)):
    y_train_pred = xgb_model.predict(X_train, iteration_range=(0, i + 1))
    y_test_pred = xgb_model.predict(X_test, iteration_range=(0, i + 1))
    
    train_r2 = r2_score(y_train, y_train_pred)
    test_r2 = r2_score(y_test, y_test_pred)
    train_r2_scores.append(train_r2)
    test_r2_scores.append(test_r2)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Train Loss (RMSE)')
plt.plot(test_loss, label='Test Loss (RMSE)')
plt.xlabel('학습횟수')
plt.ylabel('RMSE')
plt.title('Train and Test Loss')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_r2_scores, label='Train R2 Score')
plt.plot(test_r2_scores, label='Test R2 Score')
plt.xlabel('학습횟수')
plt.ylabel('R2 Score')
plt.title('Train and Test R2 Score')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

y_pred = xgb_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"\n최종 Mean Squared Error: {mse:.2f}")
print(f"최종 R2 Score: {r2:.2f}")

# 모델 저장 
joblib.dump(xgb_model, './xgboost_gyungsangbookdo_model.pkl')
# Out:
# [0]	validation_0-rmse:0.00092	validation_1-rmse:0.00090
# [1]	validation_0-rmse:0.00091	validation_1-rmse:0.00089
# [2]	validation_0-rmse:0.00090	validation_1-rmse:0.00088
# [3]	validation_0-rmse:0.00089	validation_1-rmse:0.00087
# [4]	validation_0-rmse:0.00088	validation_1-rmse:0.00086
# [5]	validation_0-rmse:0.00087	validation_1-rmse:0.00085
# [6]	validation_0-rmse:0.00087	validation_1-rmse:0.00084
# [7]	validation_0-rmse:0.00086	validation_1-rmse:0.00083
# [8]	validation_0-rmse:0.00085	validation_1-rmse:0.00083
# [9]	validation_0-rmse:0.00084	validation_1-rmse:0.00082
# [10]	validation_0-rmse:0.00083	validation_1-rmse:0.00081
# [11]	validation_0-rmse:0.00082	validation_1-rmse:0.00080
# [12]	validation_0-rmse:0.00082	validation_1-rmse:0.00079
# [13]	validation_0-rmse:0.00081	validation_1-rmse:0.00079
# [14]	validation_0-rmse:0.00080	validation_1-rmse:0.00078
# [15]	validation_0-rmse:0.00079	validation_1-rmse:0.00077
# [16]	validation_0-rmse:0.00078	validation_1-rmse:0.00076
# [17]	validation_0-rmse:0.00078	validation_1-rmse:0.00076
# [18]	validation_0-rmse:0.00077	validation_1-rmse:0.00075
# [19]	validation_0-rmse:0.00076	validation_1-rmse:0.00074
# [20]	validation_0-rmse:0.00075	validation_1-rmse:0.00073
# [21]	validation_0-rmse:0.00075	validation_1-rmse:0.00073
# [22]	validation_0-rmse:0.00074	validation_1-rmse:0.00072
# [23]	validation_0-rmse:0.00073	validation_1-rmse:0.00071
# [24]	validation_0-rmse:0.00072	validation_1-rmse:0.00070
# [25]	validation_0-rmse:0.00072	validation_1-rmse:0.00070
# [26]	validation_0-rmse:0.00071	validation_1-rmse:0.00069
# [27]	validation_0-rmse:0.00070	validation_1-rmse:0.00068
# [28]	validation_0-rmse:0.00069	validation_1-rmse:0.00068
# [29]	validation_0-rmse:0.00069	validation_1-rmse:0.00067
# [30]	validation_0-rmse:0.00068	validation_1-rmse:0.00066
# [31]	validation_0-rmse:0.00067	validation_1-rmse:0.00066
# [32]	validation_0-rmse:0.00067	validation_1-rmse:0.00065
# [33]	validation_0-rmse:0.00066	validation_1-rmse:0.00064
# [34]	validation_0-rmse:0.00065	validation_1-rmse:0.00064
# [35]	validation_0-rmse:0.00065	validation_1-rmse:0.00063
# [36]	validation_0-rmse:0.00064	validation_1-rmse:0.00062
# [37]	validation_0-rmse:0.00063	validation_1-rmse:0.00062
# [38]	validation_0-rmse:0.00063	validation_1-rmse:0.00061
# [39]	validation_0-rmse:0.00062	validation_1-rmse:0.00061
# [40]	validation_0-rmse:0.00062	validation_1-rmse:0.00060
# [41]	validation_0-rmse:0.00061	validation_1-rmse:0.00059
# [42]	validation_0-rmse:0.00060	validation_1-rmse:0.00059
# [43]	validation_0-rmse:0.00060	validation_1-rmse:0.00058
# [44]	validation_0-rmse:0.00059	validation_1-rmse:0.00058
# [45]	validation_0-rmse:0.00059	validation_1-rmse:0.00057
# [46]	validation_0-rmse:0.00058	validation_1-rmse:0.00056
# [47]	validation_0-rmse:0.00057	validation_1-rmse:0.00056
# [48]	validation_0-rmse:0.00057	validation_1-rmse:0.00055
# [49]	validation_0-rmse:0.00056	validation_1-rmse:0.00055
# [50]	validation_0-rmse:0.00056	validation_1-rmse:0.00054
# [51]	validation_0-rmse:0.00055	validation_1-rmse:0.00054
# [52]	validation_0-rmse:0.00055	validation_1-rmse:0.00053
# [53]	validation_0-rmse:0.00054	validation_1-rmse:0.00053
# [54]	validation_0-rmse:0.00054	validation_1-rmse:0.00052
# [55]	validation_0-rmse:0.00053	validation_1-rmse:0.00052
# [56]	validation_0-rmse:0.00052	validation_1-rmse:0.00051
# [57]	validation_0-rmse:0.00052	validation_1-rmse:0.00051
# [58]	validation_0-rmse:0.00051	validation_1-rmse:0.00050
# [59]	validation_0-rmse:0.00051	validation_1-rmse:0.00050
# [60]	validation_0-rmse:0.00050	validation_1-rmse:0.00049
# [61]	validation_0-rmse:0.00050	validation_1-rmse:0.00049
# [62]	validation_0-rmse:0.00049	validation_1-rmse:0.00048
# [63]	validation_0-rmse:0.00049	validation_1-rmse:0.00048
# [64]	validation_0-rmse:0.00048	validation_1-rmse:0.00047
# [65]	validation_0-rmse:0.00048	validation_1-rmse:0.00047
# [66]	validation_0-rmse:0.00047	validation_1-rmse:0.00046
# [67]	validation_0-rmse:0.00047	validation_1-rmse:0.00046
# [68]	validation_0-rmse:0.00047	validation_1-rmse:0.00045
# [69]	validation_0-rmse:0.00046	validation_1-rmse:0.00045
# [70]	validation_0-rmse:0.00046	validation_1-rmse:0.00044
# [71]	validation_0-rmse:0.00045	validation_1-rmse:0.00044
# [72]	validation_0-rmse:0.00045	validation_1-rmse:0.00044
# [73]	validation_0-rmse:0.00044	validation_1-rmse:0.00043
# [74]	validation_0-rmse:0.00044	validation_1-rmse:0.00043
# [75]	validation_0-rmse:0.00043	validation_1-rmse:0.00042
# [76]	validation_0-rmse:0.00043	validation_1-rmse:0.00042
# [77]	validation_0-rmse:0.00043	validation_1-rmse:0.00041
# [78]	validation_0-rmse:0.00042	validation_1-rmse:0.00041
# [79]	validation_0-rmse:0.00042	validation_1-rmse:0.00041
# [80]	validation_0-rmse:0.00041	validation_1-rmse:0.00040
# [81]	validation_0-rmse:0.00041	validation_1-rmse:0.00040
# [82]	validation_0-rmse:0.00040	validation_1-rmse:0.00039
# [83]	validation_0-rmse:0.00040	validation_1-rmse:0.00039
# [84]	validation_0-rmse:0.00040	validation_1-rmse:0.00039
# [85]	validation_0-rmse:0.00039	validation_1-rmse:0.00038
# [86]	validation_0-rmse:0.00039	validation_1-rmse:0.00038
# [87]	validation_0-rmse:0.00038	validation_1-rmse:0.00037
# [88]	validation_0-rmse:0.00038	validation_1-rmse:0.00037
# [89]	validation_0-rmse:0.00038	validation_1-rmse:0.00037
# [90]	validation_0-rmse:0.00037	validation_1-rmse:0.00036
# [91]	validation_0-rmse:0.00037	validation_1-rmse:0.00036
# [92]	validation_0-rmse:0.00037	validation_1-rmse:0.00036
# [93]	validation_0-rmse:0.00036	validation_1-rmse:0.00035
# [94]	validation_0-rmse:0.00036	validation_1-rmse:0.00035
# [95]	validation_0-rmse:0.00036	validation_1-rmse:0.00035
# [96]	validation_0-rmse:0.00035	validation_1-rmse:0.00034
# [97]	validation_0-rmse:0.00035	validation_1-rmse:0.00034
# [98]	validation_0-rmse:0.00034	validation_1-rmse:0.00034
# [99]	validation_0-rmse:0.00034	validation_1-rmse:0.00033
# [100]	validation_0-rmse:0.00034	validation_1-rmse:0.00033
# [101]	validation_0-rmse:0.00033	validation_1-rmse:0.00033
# [102]	validation_0-rmse:0.00033	validation_1-rmse:0.00032
# [103]	validation_0-rmse:0.00033	validation_1-rmse:0.00032
# [104]	validation_0-rmse:0.00032	validation_1-rmse:0.00032
# [105]	validation_0-rmse:0.00032	validation_1-rmse:0.00031
# [106]	validation_0-rmse:0.00032	validation_1-rmse:0.00031
# [107]	validation_0-rmse:0.00031	validation_1-rmse:0.00031
# [108]	validation_0-rmse:0.00031	validation_1-rmse:0.00030
# [109]	validation_0-rmse:0.00031	validation_1-rmse:0.00030
# [110]	validation_0-rmse:0.00031	validation_1-rmse:0.00030
# [111]	validation_0-rmse:0.00030	validation_1-rmse:0.00029
# [112]	validation_0-rmse:0.00030	validation_1-rmse:0.00029
# [113]	validation_0-rmse:0.00030	validation_1-rmse:0.00029
# [114]	validation_0-rmse:0.00029	validation_1-rmse:0.00029
# [115]	validation_0-rmse:0.00029	validation_1-rmse:0.00028
# [116]	validation_0-rmse:0.00029	validation_1-rmse:0.00028
# [117]	validation_0-rmse:0.00028	validation_1-rmse:0.00028
# [118]	validation_0-rmse:0.00028	validation_1-rmse:0.00027
# [119]	validation_0-rmse:0.00028	validation_1-rmse:0.00027
# [120]	validation_0-rmse:0.00028	validation_1-rmse:0.00027
# [121]	validation_0-rmse:0.00027	validation_1-rmse:0.00027
# [122]	validation_0-rmse:0.00027	validation_1-rmse:0.00026
# [123]	validation_0-rmse:0.00027	validation_1-rmse:0.00026
# [124]	validation_0-rmse:0.00027	validation_1-rmse:0.00026
# [125]	validation_0-rmse:0.00026	validation_1-rmse:0.00026
# [126]	validation_0-rmse:0.00026	validation_1-rmse:0.00025
# [127]	validation_0-rmse:0.00026	validation_1-rmse:0.00025
# [128]	validation_0-rmse:0.00026	validation_1-rmse:0.00025
# [129]	validation_0-rmse:0.00025	validation_1-rmse:0.00025
# [130]	validation_0-rmse:0.00025	validation_1-rmse:0.00024
# [131]	validation_0-rmse:0.00025	validation_1-rmse:0.00024
# [132]	validation_0-rmse:0.00025	validation_1-rmse:0.00024
# [133]	validation_0-rmse:0.00024	validation_1-rmse:0.00024
# [134]	validation_0-rmse:0.00024	validation_1-rmse:0.00023
# [135]	validation_0-rmse:0.00024	validation_1-rmse:0.00023
# [136]	validation_0-rmse:0.00024	validation_1-rmse:0.00023
# [137]	validation_0-rmse:0.00023	validation_1-rmse:0.00023
# [138]	validation_0-rmse:0.00023	validation_1-rmse:0.00022
# [139]	validation_0-rmse:0.00023	validation_1-rmse:0.00022
# [140]	validation_0-rmse:0.00023	validation_1-rmse:0.00022
# [141]	validation_0-rmse:0.00022	validation_1-rmse:0.00022
# [142]	validation_0-rmse:0.00022	validation_1-rmse:0.00022
# [143]	validation_0-rmse:0.00022	validation_1-rmse:0.00021
# [144]	validation_0-rmse:0.00022	validation_1-rmse:0.00021
# [145]	validation_0-rmse:0.00022	validation_1-rmse:0.00021
# [146]	validation_0-rmse:0.00021	validation_1-rmse:0.00021
# [147]	validation_0-rmse:0.00021	validation_1-rmse:0.00021
# [148]	validation_0-rmse:0.00021	validation_1-rmse:0.00020
# [149]	validation_0-rmse:0.00021	validation_1-rmse:0.00020
# [150]	validation_0-rmse:0.00020	validation_1-rmse:0.00020
# [151]	validation_0-rmse:0.00020	validation_1-rmse:0.00020
# [152]	validation_0-rmse:0.00020	validation_1-rmse:0.00020
# [153]	validation_0-rmse:0.00020	validation_1-rmse:0.00019
# [154]	validation_0-rmse:0.00020	validation_1-rmse:0.00019
# [155]	validation_0-rmse:0.00019	validation_1-rmse:0.00019
# [156]	validation_0-rmse:0.00019	validation_1-rmse:0.00019
# [157]	validation_0-rmse:0.00019	validation_1-rmse:0.00019
# [158]	validation_0-rmse:0.00019	validation_1-rmse:0.00018
# [159]	validation_0-rmse:0.00019	validation_1-rmse:0.00018
# [160]	validation_0-rmse:0.00019	validation_1-rmse:0.00018
# [161]	validation_0-rmse:0.00018	validation_1-rmse:0.00018
# [162]	validation_0-rmse:0.00018	validation_1-rmse:0.00018
# [163]	validation_0-rmse:0.00018	validation_1-rmse:0.00017
# [164]	validation_0-rmse:0.00018	validation_1-rmse:0.00017
# [165]	validation_0-rmse:0.00018	validation_1-rmse:0.00017
# [166]	validation_0-rmse:0.00017	validation_1-rmse:0.00017
# [167]	validation_0-rmse:0.00017	validation_1-rmse:0.00017
# [168]	validation_0-rmse:0.00017	validation_1-rmse:0.00017
# [169]	validation_0-rmse:0.00017	validation_1-rmse:0.00016
# 최종 Mean Squared Error: 0.00
# 최종 R2 Score: 0.97
# ['./xgboost_gyungsangbookdo_model.pkl']

# %%
y_pred = xgb_model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'MSE: {mse}, R2: {r2}')
# Out:
# MSE: 2.7104423155193037e-08, R2: 0.9668249341515888

# %%
xgb_model = joblib.load('./xgboost_gyungsangbookdo_model.pkl')

scaler = StandardScaler()
scaler.fit(X_train)  
input_data = {
    '진료과목_인코딩': [2],  
    '지역_인코딩': [3],         # 고정값
    '의료기관_인코딩': [0], 
    '최종수가_표준화': [-0.65],  
    'K-MEAN 군집': [38], 
    '경상북도_건강보험': [-0.659],
    '의료수가_표준화': [1.8706],
    "경상북도_소아과 병원 수_표준화" :[900],
    "경상북도_소아과 의료인력 수_표준화" :[0.9]
}
input_df = pd.DataFrame(input_data)

input_scaled = scaler.transform(input_df)

prediction_1 = xgb_model.predict(input_scaled)
print(f'예측 결과: {prediction_1[0]} (표준화된 소아과 병원 수)')
# Out:
# 예측 결과: 0.10873109847307205 (표준화된 소아과 병원 수)
