# %%
from sklearn.datasets import make_moons
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
from sklearn.impute import KNNImputer
import pandas as pd
import matplotlib.pyplot as plt
import koreanize_matplotlib
from tabulate import tabulate 
import glob

from sklearn.preprocessing import LabelEncoder
import seaborn as sns

from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.metrics import mean_squared_error, r2_score
import joblib

# %%
NABIS = pd.read_csv("./진짜 진짜 진짜로 전처리 완료된 대회 분석 데이터.csv")
NABIS = pd.DataFrame(NABIS)
NABIS
# Out:
#       Unnamed: 0    연도    의료수가   가중치  지역 소아과 수        최종수가  강원특별자치도_건강보험  \
# 0              0  2019  258854  74.9       864  19388164.6       1491120
# 1              1  2019  258854  83.4       864  21588423.6       1491120
# 2              2  2019  258854  74.9     10940  19388164.6       1491120
# 3              3  2019  258854  83.4     10940  21588423.6       1491120
# 4              4  2019  258854  74.9      8032  19388164.6       1491120
# ...          ...   ...     ...   ...       ...         ...           ...
# 1787        1787  2022  617545  78.4      8032  48415528.0       1503671
# 1788        1788  2022  617545  78.4       996  48415528.0       1503671
# 1789        1789  2022  617545  90.2       996  55702559.0       1503671
# 1790        1790  2022  617545  78.4       816  48415528.0       1503671
# 1791        1791  2022  617545  90.2       816  55702559.0       1503671
#
#       강원특별자치도_소아과 병원 수  강원특별자치도_소아과 의료인력 수  강원특별자치도_천명당 소아과 수  ...  \
# 0                  864                 527           0.142105  ...
# 1                  864                 527           0.142105  ...
# 2                  864                 527           0.142105  ...
# 3                  864                 527           0.142105  ...
# 4                  864                 527           0.142105  ...
# ...                ...                 ...                ...  ...
# 1787               904                 618           0.148003  ...
# 1788               904                 618           0.148003  ...
# 1789               904                 618           0.148003  ...
# 1790               904                 618           0.148003  ...
# 1791               904                 618           0.148003  ...
#
#       전북특별자치도_소아과 병원 수_표준화  전북특별자치도_소아과 의료인력 수_표준화  전라남도_소아과 병원 수_표준화  \
# 0                 1.532478               -0.463988           1.310556
# 1                 1.532478               -0.463988           1.310556
# 2                 1.532478               -0.463988           1.310556
# 3                 1.532478               -0.463988           1.310556
# 4                 1.532478               -0.463988           1.310556
# ...                    ...                     ...                ...
# 1787             -0.998219                1.716757          -0.087370
# 1788             -0.998219                1.716757          -0.087370
# 1789             -0.998219                1.716757          -0.087370
# 1790             -0.998219                1.716757          -0.087370
# 1791             -0.998219                1.716757          -0.087370
#
#       전라남도_소아과 의료인력 수_표준화  경상북도_소아과 병원 수_표준화  경상북도_소아과 의료인력 수_표준화  \
# 0                0.110959           0.848528             1.163333
# 1                0.110959           0.848528             1.163333
# 2                0.110959           0.848528             1.163333
# 3                0.110959           0.848528             1.163333
# 4                0.110959           0.848528             1.163333
# ...                   ...                ...                  ...
# 1787            -0.776713          -0.848528            -1.398134
# 1788            -0.776713          -0.848528            -1.398134
# 1789            -0.776713          -0.848528            -1.398134
# 1790            -0.776713          -0.848528            -1.398134
# 1791            -0.776713          -0.848528            -1.398134
#
#       경상남도_소아과 병원 수_표준화  경상남도_소아과 의료인력 수_표준화  제주특별자치도_소아과 병원 수_표준화  \
# 0              1.427416            -1.091442             -1.647064
# 1              1.427416            -1.091442             -1.647064
# 2              1.427416            -1.091442             -1.647064
# 3              1.427416            -1.091442             -1.647064
# 4              1.427416            -1.091442             -1.647064
# ...                 ...                  ...                   ...
# 1787          -0.965205             1.570042              0.930949
# 1788          -0.965205             1.570042              0.930949
# 1789          -0.965205             1.570042              0.930949
# 1790          -0.965205             1.570042              0.930949
# 1791          -0.965205             1.570042              0.930949
#
#       제주특별자치도_소아과 의료인력 수_표준화
# 0                  -1.598822
# 1                  -1.598822
# 2                  -1.598822
# 3                  -1.598822
# 4                  -1.598822
# ...                      ...
# 1787                1.157767
# 1788                1.157767
# 1789                1.157767
# 1790                1.157767
# 1791                1.157767
#
# [1792 rows x 121 columns]

# %%
from sklearn.cluster import KMeans

features = NABIS[['진료과목_인코딩', '지역_인코딩', '의료기관_인코딩', '최종수가_표준화', '전북특별자치도 건강보험_표준화', '전북특별자치도_소아과 병원 수_표준화', "전북특별자치도_소아과 의료인력 수_표준화", "전북특별자치도_천명당 소아과 수"]]

# n_clusters: 군집 개수를 설정 
n_clusters = 4
kmeans = KMeans(n_clusters=n_clusters, random_state=43)

NABIS['K-MEAN 군집'] = kmeans.fit_predict(features)

KGoonjib = './K-MEAN 전북특별자치도 군집화 결과2.xlsx'
NABIS.to_excel(KGoonjib, index=False)

NABIS['K-MEAN 군집'].value_counts()
# Out:
# K-MEAN 군집
# 3    448
# 0    448
# 1    448
# 2    448
# Name: count, dtype: int64

# %%
# Elbow 방법으로 SSE(군집내 제곱합)을 계산하여 최적의 군집 수 찾기
sse = []  
k_range = range(1, 40)  

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=43)
    kmeans.fit(features)
    sse.append(kmeans.inertia_)  

plt.figure(figsize=(10, 6))
plt.plot(k_range, sse, marker='o')
plt.xlabel('K')
plt.ylabel('SSE')
plt.title('Elbow의 최적의 군집 수')
plt.xticks(k_range)
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import silhouette_score

# 실루엣 계수로 최적의 군집 수 찾기
silhouette_scores = []
k_range = range(2, 50)  

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=43)
    cluster_labels = kmeans.fit_predict(features)
    silhouette_avg = silhouette_score(features, cluster_labels)
    silhouette_scores.append(silhouette_avg)

plt.figure(figsize=(10, 6))
plt.plot(k_range, silhouette_scores, marker='o')
plt.xlabel('k')
plt.ylabel('실루엣 스코어')
plt.title('Silhouette Score의 최적의 군집 수')
plt.xticks(k_range)
plt.grid(True)
plt.show()

# %%
# k-mean 군집화 분석 

Kcluster_counts = NABIS['K-MEAN 군집'].value_counts()
print("\n군집별 데이터 수:\n", Kcluster_counts)

Kcluster_means = NABIS.groupby('K-MEAN 군집').mean()
print("\n군집별 평균값:\n", Kcluster_means)

plt.figure(figsize=(10, 6))
sns.boxplot(x='K-MEAN 군집', y='최종수가_표준화', data=NABIS)
plt.title('군집별 최종수가_표준화 분포')
plt.xlabel('군집')
plt.ylabel('최종수가_표준화')
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x='K-MEAN 군집', y='지역 소아과 수', data=NABIS)
plt.title('군집별 지역 소아과 수 분포')
plt.xlabel('군집')
plt.ylabel('지역 소아과 수')
plt.grid(True)
plt.show()
# Out:
# 군집별 데이터 수:
#  K-MEAN 군집
# 3    448
# 0    448
# 1    448
# 2    448
# Name: count, dtype: int64
#
# 군집별 평균값:
#             Unnamed: 0      연도          의료수가        가중치  지역 소아과 수  \
# K-MEAN 군집
# 0               455.5  2020.5  1.319681e+06  79.840625    4613.5
# 1              1335.5  2020.5  1.615130e+06  80.468750    4199.5
# 2              1351.5  2020.5  1.615130e+06  79.840625    4613.5
# 3               439.5  2020.5  1.319681e+06  80.468750    4199.5
#
#                    최종수가  강원특별자치도_건강보험  강원특별자치도_소아과 병원 수  강원특별자치도_소아과 의료인력 수  \
# K-MEAN 군집
# 0          1.054398e+08     1497294.5             887.0               565.5
# 1          1.298619e+08     1497294.5             887.0               565.5
# 2          1.288517e+08     1497294.5             887.0               565.5
# 3          1.062719e+08     1497294.5             887.0               565.5
#
#            강원특별자치도_천명당 소아과 수  ...  전북특별자치도_소아과 병원 수_표준화  \
# K-MEAN 군집                     ...
# 0                   0.145742  ...         -2.775558e-17
# 1                   0.145742  ...         -2.775558e-17
# 2                   0.145742  ...         -2.775558e-17
# 3                   0.145742  ...         -2.775558e-17
#
#            전북특별자치도_소아과 의료인력 수_표준화  전라남도_소아과 병원 수_표준화  전라남도_소아과 의료인력 수_표준화  \
# K-MEAN 군집
# 0                    2.775558e-17      -6.938894e-18        -2.775558e-17
# 1                    2.775558e-17      -6.938894e-18        -2.775558e-17
# 2                    2.775558e-17      -6.938894e-18        -2.775558e-17
# 3                    2.775558e-17      -6.938894e-18        -2.775558e-17
#
#            경상북도_소아과 병원 수_표준화  경상북도_소아과 의료인력 수_표준화  경상남도_소아과 병원 수_표준화  \
# K-MEAN 군집
# 0                        0.0                  0.0      -5.551115e-17
# 1                        0.0                  0.0      -5.551115e-17
# 2                        0.0                  0.0      -5.551115e-17
# 3                        0.0                  0.0      -5.551115e-17
#
#            경상남도_소아과 의료인력 수_표준화  제주특별자치도_소아과 병원 수_표준화  제주특별자치도_소아과 의료인력 수_표준화
# K-MEAN 군집
# 0                 3.122502e-17                   0.0            2.081668e-17
# 1                 3.122502e-17                   0.0            2.081668e-17
# 2                 3.122502e-17                   0.0            2.081668e-17
# 3                 3.122502e-17                   0.0            2.081668e-17
#
# [4 rows x 121 columns]

# %%
# PCA
from sklearn.decomposition import PCA
NABIS1 = NABIS.copy()

# 2차원 축소
pca = PCA(n_components=2)
pca_result = pca.fit_transform(features)

NABIS1['PCA1'] = pca_result[:, 0]
NABIS1['PCA2'] = pca_result[:, 1]

plt.figure(figsize=(12, 8))
sns.scatterplot(x='PCA1', y='PCA2', hue='K-MEAN 군집', palette='Set1', data=NABIS1, s=50, alpha=0.7, edgecolor='k')
plt.title('주성분 분석')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.legend(title='Cluster')
plt.grid(True)
plt.show()

# %%
NABIS.columns
# Out:
# Index(['Unnamed: 0', '연도', '의료수가', '가중치', '지역 소아과 수', '최종수가', '강원특별자치도_건강보험',
#        '강원특별자치도_소아과 병원 수', '강원특별자치도_소아과 의료인력 수', '강원특별자치도_천명당 소아과 수',
#        ...
#        '전북특별자치도_소아과 의료인력 수_표준화', '전라남도_소아과 병원 수_표준화', '전라남도_소아과 의료인력 수_표준화',
#        '경상북도_소아과 병원 수_표준화', '경상북도_소아과 의료인력 수_표준화', '경상남도_소아과 병원 수_표준화',
#        '경상남도_소아과 의료인력 수_표준화', '제주특별자치도_소아과 병원 수_표준화', '제주특별자치도_소아과 의료인력 수_표준화',
#        'K-MEAN 군집'],
#       dtype='object', length=122)

# %%
X = NABIS[['진료과목_인코딩', '지역_인코딩', '의료기관_인코딩', '최종수가_표준화', 'K-MEAN 군집', '전북특별자치도 건강보험_표준화', '의료수가_표준화', "전북특별자치도_소아과 병원 수_표준화",
           "전북특별자치도_소아과 의료인력 수_표준화", "전북특별자치도_소아과 병원 수"]]
y = NABIS['전북특별자치도_천명당 소아과 수']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43)

xgb_model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=170, learning_rate=0.01, max_depth=7, random_state=43)

# 모델 학습
xgb_model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_test, y_test)], verbose=True)

evals_result = xgb_model.evals_result()
train_loss = evals_result['validation_0']['rmse']
test_loss = evals_result['validation_1']['rmse']

train_r2_scores = []
test_r2_scores = []

for i in range(len(train_loss)):
    y_train_pred = xgb_model.predict(X_train, iteration_range=(0, i + 1))
    y_test_pred = xgb_model.predict(X_test, iteration_range=(0, i + 1))
    
    train_r2 = r2_score(y_train, y_train_pred)
    test_r2 = r2_score(y_test, y_test_pred)
    train_r2_scores.append(train_r2)
    test_r2_scores.append(test_r2)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Train Loss (RMSE)')
plt.plot(test_loss, label='Test Loss (RMSE)')
plt.xlabel('학습횟수')
plt.ylabel('RMSE')
plt.title('Train and Test Loss')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_r2_scores, label='Train R2 Score')
plt.plot(test_r2_scores, label='Test R2 Score')
plt.xlabel('학습횟수')
plt.ylabel('R2 Score')
plt.title('Train and Test R2 Score')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

y_pred = xgb_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"\n최종 Mean Squared Error: {mse:.2f}")
print(f"최종 R2 Score: {r2:.2f}")

# 모델 저장 
joblib.dump(xgb_model, './xgboost_jeonlabookdo_model.pkl')
# Out:
# [0]	validation_0-rmse:0.00870	validation_1-rmse:0.00894
# [1]	validation_0-rmse:0.00861	validation_1-rmse:0.00885
# [2]	validation_0-rmse:0.00853	validation_1-rmse:0.00876
# [3]	validation_0-rmse:0.00844	validation_1-rmse:0.00867
# [4]	validation_0-rmse:0.00836	validation_1-rmse:0.00859
# [5]	validation_0-rmse:0.00828	validation_1-rmse:0.00850
# [6]	validation_0-rmse:0.00819	validation_1-rmse:0.00842
# [7]	validation_0-rmse:0.00811	validation_1-rmse:0.00833
# [8]	validation_0-rmse:0.00803	validation_1-rmse:0.00825
# [9]	validation_0-rmse:0.00795	validation_1-rmse:0.00817
# [10]	validation_0-rmse:0.00787	validation_1-rmse:0.00808
# [11]	validation_0-rmse:0.00779	validation_1-rmse:0.00800
# [12]	validation_0-rmse:0.00771	validation_1-rmse:0.00792
# [13]	validation_0-rmse:0.00764	validation_1-rmse:0.00785
# [14]	validation_0-rmse:0.00756	validation_1-rmse:0.00777
# [15]	validation_0-rmse:0.00749	validation_1-rmse:0.00769
# [16]	validation_0-rmse:0.00741	validation_1-rmse:0.00761
# [17]	validation_0-rmse:0.00734	validation_1-rmse:0.00754
# [18]	validation_0-rmse:0.00726	validation_1-rmse:0.00746
# [19]	validation_0-rmse:0.00719	validation_1-rmse:0.00739
# [20]	validation_0-rmse:0.00712	validation_1-rmse:0.00731
# [21]	validation_0-rmse:0.00705	validation_1-rmse:0.00724
# [22]	validation_0-rmse:0.00698	validation_1-rmse:0.00717
# [23]	validation_0-rmse:0.00691	validation_1-rmse:0.00710
# [24]	validation_0-rmse:0.00684	validation_1-rmse:0.00703
# [25]	validation_0-rmse:0.00677	validation_1-rmse:0.00696
# [26]	validation_0-rmse:0.00670	validation_1-rmse:0.00689
# [27]	validation_0-rmse:0.00664	validation_1-rmse:0.00682
# [28]	validation_0-rmse:0.00657	validation_1-rmse:0.00675
# [29]	validation_0-rmse:0.00651	validation_1-rmse:0.00668
# [30]	validation_0-rmse:0.00644	validation_1-rmse:0.00662
# [31]	validation_0-rmse:0.00638	validation_1-rmse:0.00655
# [32]	validation_0-rmse:0.00631	validation_1-rmse:0.00649
# [33]	validation_0-rmse:0.00625	validation_1-rmse:0.00642
# [34]	validation_0-rmse:0.00619	validation_1-rmse:0.00636
# [35]	validation_0-rmse:0.00613	validation_1-rmse:0.00629
# [36]	validation_0-rmse:0.00607	validation_1-rmse:0.00623
# [37]	validation_0-rmse:0.00601	validation_1-rmse:0.00617
# [38]	validation_0-rmse:0.00595	validation_1-rmse:0.00611
# [39]	validation_0-rmse:0.00589	validation_1-rmse:0.00605
# [40]	validation_0-rmse:0.00583	validation_1-rmse:0.00599
# [41]	validation_0-rmse:0.00577	validation_1-rmse:0.00593
# [42]	validation_0-rmse:0.00571	validation_1-rmse:0.00587
# [43]	validation_0-rmse:0.00565	validation_1-rmse:0.00581
# [44]	validation_0-rmse:0.00560	validation_1-rmse:0.00575
# [45]	validation_0-rmse:0.00554	validation_1-rmse:0.00569
# [46]	validation_0-rmse:0.00549	validation_1-rmse:0.00564
# [47]	validation_0-rmse:0.00543	validation_1-rmse:0.00558
# [48]	validation_0-rmse:0.00538	validation_1-rmse:0.00552
# [49]	validation_0-rmse:0.00532	validation_1-rmse:0.00547
# [50]	validation_0-rmse:0.00527	validation_1-rmse:0.00541
# [51]	validation_0-rmse:0.00522	validation_1-rmse:0.00536
# [52]	validation_0-rmse:0.00517	validation_1-rmse:0.00531
# [53]	validation_0-rmse:0.00512	validation_1-rmse:0.00525
# [54]	validation_0-rmse:0.00506	validation_1-rmse:0.00520
# [55]	validation_0-rmse:0.00501	validation_1-rmse:0.00515
# [56]	validation_0-rmse:0.00496	validation_1-rmse:0.00510
# [57]	validation_0-rmse:0.00491	validation_1-rmse:0.00505
# [58]	validation_0-rmse:0.00487	validation_1-rmse:0.00500
# [59]	validation_0-rmse:0.00482	validation_1-rmse:0.00495
# [60]	validation_0-rmse:0.00477	validation_1-rmse:0.00490
# [61]	validation_0-rmse:0.00472	validation_1-rmse:0.00485
# [62]	validation_0-rmse:0.00467	validation_1-rmse:0.00480
# [63]	validation_0-rmse:0.00463	validation_1-rmse:0.00475
# [64]	validation_0-rmse:0.00458	validation_1-rmse:0.00471
# [65]	validation_0-rmse:0.00454	validation_1-rmse:0.00466
# [66]	validation_0-rmse:0.00449	validation_1-rmse:0.00461
# [67]	validation_0-rmse:0.00445	validation_1-rmse:0.00457
# [68]	validation_0-rmse:0.00440	validation_1-rmse:0.00452
# [69]	validation_0-rmse:0.00436	validation_1-rmse:0.00448
# [70]	validation_0-rmse:0.00431	validation_1-rmse:0.00443
# [71]	validation_0-rmse:0.00427	validation_1-rmse:0.00439
# [72]	validation_0-rmse:0.00423	validation_1-rmse:0.00434
# [73]	validation_0-rmse:0.00419	validation_1-rmse:0.00430
# [74]	validation_0-rmse:0.00414	validation_1-rmse:0.00426
# [75]	validation_0-rmse:0.00410	validation_1-rmse:0.00421
# [76]	validation_0-rmse:0.00406	validation_1-rmse:0.00417
# [77]	validation_0-rmse:0.00402	validation_1-rmse:0.00413
# [78]	validation_0-rmse:0.00398	validation_1-rmse:0.00409
# [79]	validation_0-rmse:0.00394	validation_1-rmse:0.00405
# [80]	validation_0-rmse:0.00390	validation_1-rmse:0.00401
# [81]	validation_0-rmse:0.00386	validation_1-rmse:0.00397
# [82]	validation_0-rmse:0.00383	validation_1-rmse:0.00393
# [83]	validation_0-rmse:0.00379	validation_1-rmse:0.00389
# [84]	validation_0-rmse:0.00375	validation_1-rmse:0.00385
# [85]	validation_0-rmse:0.00371	validation_1-rmse:0.00381
# [86]	validation_0-rmse:0.00367	validation_1-rmse:0.00377
# [87]	validation_0-rmse:0.00364	validation_1-rmse:0.00374
# [88]	validation_0-rmse:0.00360	validation_1-rmse:0.00370
# [89]	validation_0-rmse:0.00357	validation_1-rmse:0.00366
# [90]	validation_0-rmse:0.00353	validation_1-rmse:0.00363
# [91]	validation_0-rmse:0.00350	validation_1-rmse:0.00359
# [92]	validation_0-rmse:0.00346	validation_1-rmse:0.00355
# [93]	validation_0-rmse:0.00343	validation_1-rmse:0.00352
# [94]	validation_0-rmse:0.00339	validation_1-rmse:0.00348
# [95]	validation_0-rmse:0.00336	validation_1-rmse:0.00345
# [96]	validation_0-rmse:0.00332	validation_1-rmse:0.00341
# [97]	validation_0-rmse:0.00329	validation_1-rmse:0.00338
# [98]	validation_0-rmse:0.00326	validation_1-rmse:0.00335
# [99]	validation_0-rmse:0.00323	validation_1-rmse:0.00331
# [100]	validation_0-rmse:0.00319	validation_1-rmse:0.00328
# [101]	validation_0-rmse:0.00316	validation_1-rmse:0.00325
# [102]	validation_0-rmse:0.00313	validation_1-rmse:0.00322
# [103]	validation_0-rmse:0.00310	validation_1-rmse:0.00318
# [104]	validation_0-rmse:0.00307	validation_1-rmse:0.00315
# [105]	validation_0-rmse:0.00304	validation_1-rmse:0.00312
# [106]	validation_0-rmse:0.00301	validation_1-rmse:0.00309
# [107]	validation_0-rmse:0.00298	validation_1-rmse:0.00306
# [108]	validation_0-rmse:0.00295	validation_1-rmse:0.00303
# [109]	validation_0-rmse:0.00292	validation_1-rmse:0.00300
# [110]	validation_0-rmse:0.00289	validation_1-rmse:0.00297
# [111]	validation_0-rmse:0.00286	validation_1-rmse:0.00294
# [112]	validation_0-rmse:0.00283	validation_1-rmse:0.00291
# [113]	validation_0-rmse:0.00280	validation_1-rmse:0.00288
# [114]	validation_0-rmse:0.00278	validation_1-rmse:0.00285
# [115]	validation_0-rmse:0.00275	validation_1-rmse:0.00282
# [116]	validation_0-rmse:0.00272	validation_1-rmse:0.00279
# [117]	validation_0-rmse:0.00269	validation_1-rmse:0.00277
# [118]	validation_0-rmse:0.00267	validation_1-rmse:0.00274
# [119]	validation_0-rmse:0.00264	validation_1-rmse:0.00271
# [120]	validation_0-rmse:0.00261	validation_1-rmse:0.00268
# [121]	validation_0-rmse:0.00259	validation_1-rmse:0.00266
# [122]	validation_0-rmse:0.00256	validation_1-rmse:0.00263
# [123]	validation_0-rmse:0.00254	validation_1-rmse:0.00261
# [124]	validation_0-rmse:0.00251	validation_1-rmse:0.00258
# [125]	validation_0-rmse:0.00249	validation_1-rmse:0.00255
# [126]	validation_0-rmse:0.00246	validation_1-rmse:0.00253
# [127]	validation_0-rmse:0.00244	validation_1-rmse:0.00250
# [128]	validation_0-rmse:0.00241	validation_1-rmse:0.00248
# [129]	validation_0-rmse:0.00239	validation_1-rmse:0.00245
# [130]	validation_0-rmse:0.00236	validation_1-rmse:0.00243
# [131]	validation_0-rmse:0.00234	validation_1-rmse:0.00240
# [132]	validation_0-rmse:0.00232	validation_1-rmse:0.00238
# [133]	validation_0-rmse:0.00229	validation_1-rmse:0.00236
# [134]	validation_0-rmse:0.00227	validation_1-rmse:0.00233
# [135]	validation_0-rmse:0.00225	validation_1-rmse:0.00231
# [136]	validation_0-rmse:0.00223	validation_1-rmse:0.00229
# [137]	validation_0-rmse:0.00220	validation_1-rmse:0.00226
# [138]	validation_0-rmse:0.00218	validation_1-rmse:0.00224
# [139]	validation_0-rmse:0.00216	validation_1-rmse:0.00222
# [140]	validation_0-rmse:0.00214	validation_1-rmse:0.00220
# [141]	validation_0-rmse:0.00212	validation_1-rmse:0.00218
# [142]	validation_0-rmse:0.00210	validation_1-rmse:0.00215
# [143]	validation_0-rmse:0.00208	validation_1-rmse:0.00213
# [144]	validation_0-rmse:0.00205	validation_1-rmse:0.00211
# [145]	validation_0-rmse:0.00203	validation_1-rmse:0.00209
# [146]	validation_0-rmse:0.00201	validation_1-rmse:0.00207
# [147]	validation_0-rmse:0.00199	validation_1-rmse:0.00205
# [148]	validation_0-rmse:0.00197	validation_1-rmse:0.00203
# [149]	validation_0-rmse:0.00195	validation_1-rmse:0.00201
# [150]	validation_0-rmse:0.00194	validation_1-rmse:0.00199
# [151]	validation_0-rmse:0.00192	validation_1-rmse:0.00197
# [152]	validation_0-rmse:0.00190	validation_1-rmse:0.00195
# [153]	validation_0-rmse:0.00188	validation_1-rmse:0.00193
# [154]	validation_0-rmse:0.00186	validation_1-rmse:0.00191
# [155]	validation_0-rmse:0.00184	validation_1-rmse:0.00189
# [156]	validation_0-rmse:0.00182	validation_1-rmse:0.00187
# [157]	validation_0-rmse:0.00180	validation_1-rmse:0.00185
# [158]	validation_0-rmse:0.00179	validation_1-rmse:0.00183
# [159]	validation_0-rmse:0.00177	validation_1-rmse:0.00182
# [160]	validation_0-rmse:0.00175	validation_1-rmse:0.00180
# [161]	validation_0-rmse:0.00173	validation_1-rmse:0.00178
# [162]	validation_0-rmse:0.00172	validation_1-rmse:0.00176
# [163]	validation_0-rmse:0.00170	validation_1-rmse:0.00174
# [164]	validation_0-rmse:0.00168	validation_1-rmse:0.00173
# [165]	validation_0-rmse:0.00166	validation_1-rmse:0.00171
# [166]	validation_0-rmse:0.00165	validation_1-rmse:0.00169
# [167]	validation_0-rmse:0.00163	validation_1-rmse:0.00168
# [168]	validation_0-rmse:0.00162	validation_1-rmse:0.00166
# [169]	validation_0-rmse:0.00160	validation_1-rmse:0.00164
# 최종 Mean Squared Error: 0.00
# 최종 R2 Score: 0.97
# ['./xgboost_jeonlabookdo_model.pkl']

# %%
y_pred = xgb_model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'MSE: {mse}, R2: {r2}')
# Out:
# MSE: 2.6995443682610786e-06, R2: 0.9667362951065704

# %%
xgb_model = joblib.load('./xgboost_jeonlabookdo_model.pkl')

scaler = StandardScaler()
scaler.fit(X_train)  
input_data = {
    '진료과목_인코딩': [6],  
    '지역_인코딩': [12],         # 고정값
    '의료기관_인코딩': [1], 
    '최종수가_표준화': [0.8],  
    'K-MEAN 군집': [1], 
    '전북특별자치도 건강보험_표준화': [0],
    '의료수가_표준화': [1],
    "전북특별자치도_소아과 병원 수_표준화" :[0.9],
    "전북특별자치도_소아과 의료인력 수_표준화" :[0.9],
    "전북특별자치도_소아과 병원 수":[650]
}
input_df = pd.DataFrame(input_data)

input_scaled = scaler.transform(input_df)

prediction_1 = xgb_model.predict(input_scaled)
print(f'예측 결과: {prediction_1[0]} (표준화된 소아과 병원 수)')
# Out:
# 예측 결과: 0.14861096441745758 (표준화된 소아과 병원 수)
