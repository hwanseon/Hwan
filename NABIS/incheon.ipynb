# %%
from sklearn.datasets import make_moons
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
from sklearn.impute import KNNImputer
import pandas as pd
import matplotlib.pyplot as plt
import koreanize_matplotlib
from tabulate import tabulate 
import glob

from sklearn.preprocessing import LabelEncoder
import seaborn as sns

from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.metrics import mean_squared_error, r2_score
import joblib

# %%
NABIS = pd.read_csv("./진짜 진짜 진짜로 전처리 완료된 대회 분석 데이터.csv")
NABIS = pd.DataFrame(NABIS)
NABIS
# Out:
#       Unnamed: 0    연도    의료수가   가중치  지역 소아과 수        최종수가  강원특별자치도_건강보험  \
# 0              0  2019  258854  74.9       864  19388164.6       1491120
# 1              1  2019  258854  83.4       864  21588423.6       1491120
# 2              2  2019  258854  74.9     10940  19388164.6       1491120
# 3              3  2019  258854  83.4     10940  21588423.6       1491120
# 4              4  2019  258854  74.9      8032  19388164.6       1491120
# ...          ...   ...     ...   ...       ...         ...           ...
# 1787        1787  2022  617545  78.4      8032  48415528.0       1503671
# 1788        1788  2022  617545  78.4       996  48415528.0       1503671
# 1789        1789  2022  617545  90.2       996  55702559.0       1503671
# 1790        1790  2022  617545  78.4       816  48415528.0       1503671
# 1791        1791  2022  617545  90.2       816  55702559.0       1503671
#
#       강원특별자치도_소아과 병원 수  강원특별자치도_소아과 의료인력 수  강원특별자치도_천명당 소아과 수  ...  \
# 0                  864                 527           0.142105  ...
# 1                  864                 527           0.142105  ...
# 2                  864                 527           0.142105  ...
# 3                  864                 527           0.142105  ...
# 4                  864                 527           0.142105  ...
# ...                ...                 ...                ...  ...
# 1787               904                 618           0.148003  ...
# 1788               904                 618           0.148003  ...
# 1789               904                 618           0.148003  ...
# 1790               904                 618           0.148003  ...
# 1791               904                 618           0.148003  ...
#
#       전북특별자치도_소아과 병원 수_표준화  전북특별자치도_소아과 의료인력 수_표준화  전라남도_소아과 병원 수_표준화  \
# 0                 1.532478               -0.463988           1.310556
# 1                 1.532478               -0.463988           1.310556
# 2                 1.532478               -0.463988           1.310556
# 3                 1.532478               -0.463988           1.310556
# 4                 1.532478               -0.463988           1.310556
# ...                    ...                     ...                ...
# 1787             -0.998219                1.716757          -0.087370
# 1788             -0.998219                1.716757          -0.087370
# 1789             -0.998219                1.716757          -0.087370
# 1790             -0.998219                1.716757          -0.087370
# 1791             -0.998219                1.716757          -0.087370
#
#       전라남도_소아과 의료인력 수_표준화  경상북도_소아과 병원 수_표준화  경상북도_소아과 의료인력 수_표준화  \
# 0                0.110959           0.848528             1.163333
# 1                0.110959           0.848528             1.163333
# 2                0.110959           0.848528             1.163333
# 3                0.110959           0.848528             1.163333
# 4                0.110959           0.848528             1.163333
# ...                   ...                ...                  ...
# 1787            -0.776713          -0.848528            -1.398134
# 1788            -0.776713          -0.848528            -1.398134
# 1789            -0.776713          -0.848528            -1.398134
# 1790            -0.776713          -0.848528            -1.398134
# 1791            -0.776713          -0.848528            -1.398134
#
#       경상남도_소아과 병원 수_표준화  경상남도_소아과 의료인력 수_표준화  제주특별자치도_소아과 병원 수_표준화  \
# 0              1.427416            -1.091442             -1.647064
# 1              1.427416            -1.091442             -1.647064
# 2              1.427416            -1.091442             -1.647064
# 3              1.427416            -1.091442             -1.647064
# 4              1.427416            -1.091442             -1.647064
# ...                 ...                  ...                   ...
# 1787          -0.965205             1.570042              0.930949
# 1788          -0.965205             1.570042              0.930949
# 1789          -0.965205             1.570042              0.930949
# 1790          -0.965205             1.570042              0.930949
# 1791          -0.965205             1.570042              0.930949
#
#       제주특별자치도_소아과 의료인력 수_표준화
# 0                  -1.598822
# 1                  -1.598822
# 2                  -1.598822
# 3                  -1.598822
# 4                  -1.598822
# ...                      ...
# 1787                1.157767
# 1788                1.157767
# 1789                1.157767
# 1790                1.157767
# 1791                1.157767
#
# [1792 rows x 121 columns]

# %%
from sklearn.cluster import KMeans

features = NABIS[['진료과목_인코딩', '지역_인코딩', '의료기관_인코딩', '최종수가_표준화', '인천광역시 건강보험_표준화', '인천광역시_소아과 병원 수_표준화', "인천광역시_소아과 의료인력 수_표준화", "인천광역시_천명당 소아과 수"]]

# n_clusters: 군집 개수를 설정 
n_clusters = 4
kmeans = KMeans(n_clusters=n_clusters, random_state=43)

NABIS['K-MEAN 군집'] = kmeans.fit_predict(features)

KGoonjib = './K-MEAN 인천광역시 군집화 결과2.xlsx'
NABIS.to_excel(KGoonjib, index=False)

NABIS['K-MEAN 군집'].value_counts()
# Out:
# K-MEAN 군집
# 0    448
# 3    448
# 1    448
# 2    448
# Name: count, dtype: int64

# %%
# Elbow 방법으로 SSE(군집내 제곱합)을 계산하여 최적의 군집 수 찾기
sse = []  
k_range = range(1, 40)  

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=43)
    kmeans.fit(features)
    sse.append(kmeans.inertia_)  

plt.figure(figsize=(10, 6))
plt.plot(k_range, sse, marker='o')
plt.xlabel('K')
plt.ylabel('SSE')
plt.title('Elbow의 최적의 군집 수')
plt.xticks(k_range)
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import silhouette_score

# 실루엣 계수로 최적의 군집 수 찾기
silhouette_scores = []
k_range = range(2, 50)  

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=43)
    cluster_labels = kmeans.fit_predict(features)
    silhouette_avg = silhouette_score(features, cluster_labels)
    silhouette_scores.append(silhouette_avg)

plt.figure(figsize=(10, 6))
plt.plot(k_range, silhouette_scores, marker='o')
plt.xlabel('k')
plt.ylabel('실루엣 스코어')
plt.title('Silhouette Score의 최적의 군집 수')
plt.xticks(k_range)
plt.grid(True)
plt.show()

# %%
# k-mean 군집화 분석 

Kcluster_counts = NABIS['K-MEAN 군집'].value_counts()
print("\n군집별 데이터 수:\n", Kcluster_counts)

Kcluster_means = NABIS.groupby('K-MEAN 군집').mean()
print("\n군집별 평균값:\n", Kcluster_means)

plt.figure(figsize=(10, 6))
sns.boxplot(x='K-MEAN 군집', y='최종수가_표준화', data=NABIS)
plt.title('군집별 최종수가_표준화 분포')
plt.xlabel('군집')
plt.ylabel('최종수가_표준화')
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x='K-MEAN 군집', y='지역 소아과 수', data=NABIS)
plt.title('군집별 지역 소아과 수 분포')
plt.xlabel('군집')
plt.ylabel('지역 소아과 수')
plt.grid(True)
plt.show()
# Out:
# 군집별 데이터 수:
#  K-MEAN 군집
# 0    448
# 3    448
# 1    448
# 2    448
# Name: count, dtype: int64
#
# 군집별 평균값:
#             Unnamed: 0      연도          의료수가        가중치  지역 소아과 수  \
# K-MEAN 군집
# 0               439.5  2020.5  1.319681e+06  80.468750    4199.5
# 1              1335.5  2020.5  1.615130e+06  80.468750    4199.5
# 2              1351.5  2020.5  1.615130e+06  79.840625    4613.5
# 3               455.5  2020.5  1.319681e+06  79.840625    4613.5
#
#                    최종수가  강원특별자치도_건강보험  강원특별자치도_소아과 병원 수  강원특별자치도_소아과 의료인력 수  \
# K-MEAN 군집
# 0          1.062719e+08     1497294.5             887.0               565.5
# 1          1.298619e+08     1497294.5             887.0               565.5
# 2          1.288517e+08     1497294.5             887.0               565.5
# 3          1.054398e+08     1497294.5             887.0               565.5
#
#            강원특별자치도_천명당 소아과 수  ...  전북특별자치도_소아과 병원 수_표준화  \
# K-MEAN 군집                     ...
# 0                   0.145742  ...         -2.775558e-17
# 1                   0.145742  ...         -2.775558e-17
# 2                   0.145742  ...         -2.775558e-17
# 3                   0.145742  ...         -2.775558e-17
#
#            전북특별자치도_소아과 의료인력 수_표준화  전라남도_소아과 병원 수_표준화  전라남도_소아과 의료인력 수_표준화  \
# K-MEAN 군집
# 0                    2.775558e-17      -6.938894e-18        -2.775558e-17
# 1                    2.775558e-17      -6.938894e-18        -2.775558e-17
# 2                    2.775558e-17      -6.938894e-18        -2.775558e-17
# 3                    2.775558e-17      -6.938894e-18        -2.775558e-17
#
#            경상북도_소아과 병원 수_표준화  경상북도_소아과 의료인력 수_표준화  경상남도_소아과 병원 수_표준화  \
# K-MEAN 군집
# 0                        0.0                  0.0      -5.551115e-17
# 1                        0.0                  0.0      -5.551115e-17
# 2                        0.0                  0.0      -5.551115e-17
# 3                        0.0                  0.0      -5.551115e-17
#
#            경상남도_소아과 의료인력 수_표준화  제주특별자치도_소아과 병원 수_표준화  제주특별자치도_소아과 의료인력 수_표준화
# K-MEAN 군집
# 0                 3.122502e-17                   0.0            2.081668e-17
# 1                 3.122502e-17                   0.0            2.081668e-17
# 2                 3.122502e-17                   0.0            2.081668e-17
# 3                 3.122502e-17                   0.0            2.081668e-17
#
# [4 rows x 121 columns]

# %%
# PCA
from sklearn.decomposition import PCA
NABIS1 = NABIS.copy()

# 2차원 축소
pca = PCA(n_components=2)
pca_result = pca.fit_transform(features)

NABIS1['PCA1'] = pca_result[:, 0]
NABIS1['PCA2'] = pca_result[:, 1]

plt.figure(figsize=(12, 8))
sns.scatterplot(x='PCA1', y='PCA2', hue='K-MEAN 군집', palette='Set1', data=NABIS1, s=50, alpha=0.7, edgecolor='k')
plt.title('주성분 분석')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.legend(title='Cluster')
plt.grid(True)
plt.show()

# %%
NABIS.columns
# Out:
# Index(['Unnamed: 0', '연도', '의료수가', '가중치', '지역 소아과 수', '최종수가', '강원특별자치도_건강보험',
#        '강원특별자치도_소아과 병원 수', '강원특별자치도_소아과 의료인력 수', '강원특별자치도_천명당 소아과 수',
#        ...
#        '전북특별자치도_소아과 의료인력 수_표준화', '전라남도_소아과 병원 수_표준화', '전라남도_소아과 의료인력 수_표준화',
#        '경상북도_소아과 병원 수_표준화', '경상북도_소아과 의료인력 수_표준화', '경상남도_소아과 병원 수_표준화',
#        '경상남도_소아과 의료인력 수_표준화', '제주특별자치도_소아과 병원 수_표준화', '제주특별자치도_소아과 의료인력 수_표준화',
#        'K-MEAN 군집'],
#       dtype='object', length=122)

# %%
X = NABIS[['진료과목_인코딩', '지역_인코딩', '의료기관_인코딩', '최종수가_표준화', 'K-MEAN 군집', '인천광역시 건강보험_표준화', '의료수가_표준화', "인천광역시_소아과 병원 수_표준화",
           "인천광역시_소아과 의료인력 수_표준화", "인천광역시_소아과 병원 수"]]
y = NABIS['인천광역시_천명당 소아과 수']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43)

xgb_model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=170, learning_rate=0.01, max_depth=7, random_state=43)

# 모델 학습
xgb_model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_test, y_test)], verbose=True)

evals_result = xgb_model.evals_result()
train_loss = evals_result['validation_0']['rmse']
test_loss = evals_result['validation_1']['rmse']

train_r2_scores = []
test_r2_scores = []

for i in range(len(train_loss)):
    y_train_pred = xgb_model.predict(X_train, iteration_range=(0, i + 1))
    y_test_pred = xgb_model.predict(X_test, iteration_range=(0, i + 1))
    
    train_r2 = r2_score(y_train, y_train_pred)
    test_r2 = r2_score(y_test, y_test_pred)
    train_r2_scores.append(train_r2)
    test_r2_scores.append(test_r2)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Train Loss (RMSE)')
plt.plot(test_loss, label='Test Loss (RMSE)')
plt.xlabel('학습횟수')
plt.ylabel('RMSE')
plt.title('Train and Test Loss')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_r2_scores, label='Train R2 Score')
plt.plot(test_r2_scores, label='Test R2 Score')
plt.xlabel('학습횟수')
plt.ylabel('R2 Score')
plt.title('Train and Test R2 Score')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

y_pred = xgb_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"\n최종 Mean Squared Error: {mse:.2f}")
print(f"최종 R2 Score: {r2:.2f}")

# 모델 저장 
joblib.dump(xgb_model, './xgboost_incheon_model.pkl')
# Out:
# [0]	validation_0-rmse:0.00634	validation_1-rmse:0.00648
# [1]	validation_0-rmse:0.00628	validation_1-rmse:0.00642
# [2]	validation_0-rmse:0.00621	validation_1-rmse:0.00635
# [3]	validation_0-rmse:0.00615	validation_1-rmse:0.00629
# [4]	validation_0-rmse:0.00609	validation_1-rmse:0.00623
# [5]	validation_0-rmse:0.00603	validation_1-rmse:0.00616
# [6]	validation_0-rmse:0.00597	validation_1-rmse:0.00610
# [7]	validation_0-rmse:0.00591	validation_1-rmse:0.00604
# [8]	validation_0-rmse:0.00585	validation_1-rmse:0.00598
# [9]	validation_0-rmse:0.00579	validation_1-rmse:0.00592
# [10]	validation_0-rmse:0.00574	validation_1-rmse:0.00586
# [11]	validation_0-rmse:0.00568	validation_1-rmse:0.00580
# [12]	validation_0-rmse:0.00562	validation_1-rmse:0.00575
# [13]	validation_0-rmse:0.00557	validation_1-rmse:0.00569
# [14]	validation_0-rmse:0.00551	validation_1-rmse:0.00563
# [15]	validation_0-rmse:0.00545	validation_1-rmse:0.00558
# [16]	validation_0-rmse:0.00540	validation_1-rmse:0.00552
# [17]	validation_0-rmse:0.00535	validation_1-rmse:0.00547
# [18]	validation_0-rmse:0.00529	validation_1-rmse:0.00541
# [19]	validation_0-rmse:0.00524	validation_1-rmse:0.00536
# [20]	validation_0-rmse:0.00519	validation_1-rmse:0.00530
# [21]	validation_0-rmse:0.00514	validation_1-rmse:0.00525
# [22]	validation_0-rmse:0.00509	validation_1-rmse:0.00520
# [23]	validation_0-rmse:0.00503	validation_1-rmse:0.00515
# [24]	validation_0-rmse:0.00498	validation_1-rmse:0.00510
# [25]	validation_0-rmse:0.00493	validation_1-rmse:0.00505
# [26]	validation_0-rmse:0.00489	validation_1-rmse:0.00499
# [27]	validation_0-rmse:0.00484	validation_1-rmse:0.00494
# [28]	validation_0-rmse:0.00479	validation_1-rmse:0.00490
# [29]	validation_0-rmse:0.00474	validation_1-rmse:0.00485
# [30]	validation_0-rmse:0.00469	validation_1-rmse:0.00480
# [31]	validation_0-rmse:0.00465	validation_1-rmse:0.00475
# [32]	validation_0-rmse:0.00460	validation_1-rmse:0.00470
# [33]	validation_0-rmse:0.00455	validation_1-rmse:0.00466
# [34]	validation_0-rmse:0.00451	validation_1-rmse:0.00461
# [35]	validation_0-rmse:0.00446	validation_1-rmse:0.00456
# [36]	validation_0-rmse:0.00442	validation_1-rmse:0.00452
# [37]	validation_0-rmse:0.00438	validation_1-rmse:0.00447
# [38]	validation_0-rmse:0.00433	validation_1-rmse:0.00443
# [39]	validation_0-rmse:0.00429	validation_1-rmse:0.00438
# [40]	validation_0-rmse:0.00425	validation_1-rmse:0.00434
# [41]	validation_0-rmse:0.00420	validation_1-rmse:0.00430
# [42]	validation_0-rmse:0.00416	validation_1-rmse:0.00425
# [43]	validation_0-rmse:0.00412	validation_1-rmse:0.00421
# [44]	validation_0-rmse:0.00408	validation_1-rmse:0.00417
# [45]	validation_0-rmse:0.00404	validation_1-rmse:0.00413
# [46]	validation_0-rmse:0.00400	validation_1-rmse:0.00409
# [47]	validation_0-rmse:0.00396	validation_1-rmse:0.00405
# [48]	validation_0-rmse:0.00392	validation_1-rmse:0.00401
# [49]	validation_0-rmse:0.00388	validation_1-rmse:0.00397
# [50]	validation_0-rmse:0.00384	validation_1-rmse:0.00393
# [51]	validation_0-rmse:0.00380	validation_1-rmse:0.00389
# [52]	validation_0-rmse:0.00376	validation_1-rmse:0.00385
# [53]	validation_0-rmse:0.00373	validation_1-rmse:0.00381
# [54]	validation_0-rmse:0.00369	validation_1-rmse:0.00377
# [55]	validation_0-rmse:0.00365	validation_1-rmse:0.00373
# [56]	validation_0-rmse:0.00362	validation_1-rmse:0.00370
# [57]	validation_0-rmse:0.00358	validation_1-rmse:0.00366
# [58]	validation_0-rmse:0.00354	validation_1-rmse:0.00362
# [59]	validation_0-rmse:0.00351	validation_1-rmse:0.00359
# [60]	validation_0-rmse:0.00347	validation_1-rmse:0.00355
# [61]	validation_0-rmse:0.00344	validation_1-rmse:0.00352
# [62]	validation_0-rmse:0.00341	validation_1-rmse:0.00348
# [63]	validation_0-rmse:0.00337	validation_1-rmse:0.00345
# [64]	validation_0-rmse:0.00334	validation_1-rmse:0.00341
# [65]	validation_0-rmse:0.00330	validation_1-rmse:0.00338
# [66]	validation_0-rmse:0.00327	validation_1-rmse:0.00335
# [67]	validation_0-rmse:0.00324	validation_1-rmse:0.00331
# [68]	validation_0-rmse:0.00321	validation_1-rmse:0.00328
# [69]	validation_0-rmse:0.00317	validation_1-rmse:0.00325
# [70]	validation_0-rmse:0.00314	validation_1-rmse:0.00321
# [71]	validation_0-rmse:0.00311	validation_1-rmse:0.00318
# [72]	validation_0-rmse:0.00308	validation_1-rmse:0.00315
# [73]	validation_0-rmse:0.00305	validation_1-rmse:0.00312
# [74]	validation_0-rmse:0.00302	validation_1-rmse:0.00309
# [75]	validation_0-rmse:0.00299	validation_1-rmse:0.00306
# [76]	validation_0-rmse:0.00296	validation_1-rmse:0.00303
# [77]	validation_0-rmse:0.00293	validation_1-rmse:0.00300
# [78]	validation_0-rmse:0.00290	validation_1-rmse:0.00297
# [79]	validation_0-rmse:0.00287	validation_1-rmse:0.00294
# [80]	validation_0-rmse:0.00284	validation_1-rmse:0.00291
# [81]	validation_0-rmse:0.00282	validation_1-rmse:0.00288
# [82]	validation_0-rmse:0.00279	validation_1-rmse:0.00285
# [83]	validation_0-rmse:0.00276	validation_1-rmse:0.00282
# [84]	validation_0-rmse:0.00273	validation_1-rmse:0.00279
# [85]	validation_0-rmse:0.00270	validation_1-rmse:0.00277
# [86]	validation_0-rmse:0.00268	validation_1-rmse:0.00274
# [87]	validation_0-rmse:0.00265	validation_1-rmse:0.00271
# [88]	validation_0-rmse:0.00262	validation_1-rmse:0.00268
# [89]	validation_0-rmse:0.00260	validation_1-rmse:0.00266
# [90]	validation_0-rmse:0.00257	validation_1-rmse:0.00263
# [91]	validation_0-rmse:0.00255	validation_1-rmse:0.00260
# [92]	validation_0-rmse:0.00252	validation_1-rmse:0.00258
# [93]	validation_0-rmse:0.00250	validation_1-rmse:0.00255
# [94]	validation_0-rmse:0.00247	validation_1-rmse:0.00253
# [95]	validation_0-rmse:0.00245	validation_1-rmse:0.00250
# [96]	validation_0-rmse:0.00242	validation_1-rmse:0.00248
# [97]	validation_0-rmse:0.00240	validation_1-rmse:0.00245
# [98]	validation_0-rmse:0.00237	validation_1-rmse:0.00243
# [99]	validation_0-rmse:0.00235	validation_1-rmse:0.00240
# [100]	validation_0-rmse:0.00233	validation_1-rmse:0.00238
# [101]	validation_0-rmse:0.00230	validation_1-rmse:0.00236
# [102]	validation_0-rmse:0.00228	validation_1-rmse:0.00233
# [103]	validation_0-rmse:0.00226	validation_1-rmse:0.00231
# [104]	validation_0-rmse:0.00224	validation_1-rmse:0.00229
# [105]	validation_0-rmse:0.00221	validation_1-rmse:0.00226
# [106]	validation_0-rmse:0.00219	validation_1-rmse:0.00224
# [107]	validation_0-rmse:0.00217	validation_1-rmse:0.00222
# [108]	validation_0-rmse:0.00215	validation_1-rmse:0.00220
# [109]	validation_0-rmse:0.00213	validation_1-rmse:0.00217
# [110]	validation_0-rmse:0.00211	validation_1-rmse:0.00215
# [111]	validation_0-rmse:0.00208	validation_1-rmse:0.00213
# [112]	validation_0-rmse:0.00206	validation_1-rmse:0.00211
# [113]	validation_0-rmse:0.00204	validation_1-rmse:0.00209
# [114]	validation_0-rmse:0.00202	validation_1-rmse:0.00207
# [115]	validation_0-rmse:0.00200	validation_1-rmse:0.00205
# [116]	validation_0-rmse:0.00198	validation_1-rmse:0.00203
# [117]	validation_0-rmse:0.00196	validation_1-rmse:0.00201
# [118]	validation_0-rmse:0.00194	validation_1-rmse:0.00199
# [119]	validation_0-rmse:0.00192	validation_1-rmse:0.00197
# [120]	validation_0-rmse:0.00190	validation_1-rmse:0.00195
# [121]	validation_0-rmse:0.00189	validation_1-rmse:0.00193
# [122]	validation_0-rmse:0.00187	validation_1-rmse:0.00191
# [123]	validation_0-rmse:0.00185	validation_1-rmse:0.00189
# [124]	validation_0-rmse:0.00183	validation_1-rmse:0.00187
# [125]	validation_0-rmse:0.00181	validation_1-rmse:0.00185
# [126]	validation_0-rmse:0.00179	validation_1-rmse:0.00183
# [127]	validation_0-rmse:0.00178	validation_1-rmse:0.00182
# [128]	validation_0-rmse:0.00176	validation_1-rmse:0.00180
# [129]	validation_0-rmse:0.00174	validation_1-rmse:0.00178
# [130]	validation_0-rmse:0.00172	validation_1-rmse:0.00176
# [131]	validation_0-rmse:0.00171	validation_1-rmse:0.00174
# [132]	validation_0-rmse:0.00169	validation_1-rmse:0.00173
# [133]	validation_0-rmse:0.00167	validation_1-rmse:0.00171
# [134]	validation_0-rmse:0.00166	validation_1-rmse:0.00169
# [135]	validation_0-rmse:0.00164	validation_1-rmse:0.00168
# [136]	validation_0-rmse:0.00162	validation_1-rmse:0.00166
# [137]	validation_0-rmse:0.00161	validation_1-rmse:0.00164
# [138]	validation_0-rmse:0.00159	validation_1-rmse:0.00163
# [139]	validation_0-rmse:0.00157	validation_1-rmse:0.00161
# [140]	validation_0-rmse:0.00156	validation_1-rmse:0.00159
# [141]	validation_0-rmse:0.00154	validation_1-rmse:0.00158
# [142]	validation_0-rmse:0.00153	validation_1-rmse:0.00156
# [143]	validation_0-rmse:0.00151	validation_1-rmse:0.00155
# [144]	validation_0-rmse:0.00150	validation_1-rmse:0.00153
# [145]	validation_0-rmse:0.00148	validation_1-rmse:0.00152
# [146]	validation_0-rmse:0.00147	validation_1-rmse:0.00150
# [147]	validation_0-rmse:0.00145	validation_1-rmse:0.00149
# [148]	validation_0-rmse:0.00144	validation_1-rmse:0.00147
# [149]	validation_0-rmse:0.00142	validation_1-rmse:0.00146
# [150]	validation_0-rmse:0.00141	validation_1-rmse:0.00144
# [151]	validation_0-rmse:0.00140	validation_1-rmse:0.00143
# [152]	validation_0-rmse:0.00138	validation_1-rmse:0.00141
# [153]	validation_0-rmse:0.00137	validation_1-rmse:0.00140
# [154]	validation_0-rmse:0.00135	validation_1-rmse:0.00138
# [155]	validation_0-rmse:0.00134	validation_1-rmse:0.00137
# [156]	validation_0-rmse:0.00133	validation_1-rmse:0.00136
# [157]	validation_0-rmse:0.00131	validation_1-rmse:0.00134
# [158]	validation_0-rmse:0.00130	validation_1-rmse:0.00133
# [159]	validation_0-rmse:0.00129	validation_1-rmse:0.00132
# [160]	validation_0-rmse:0.00128	validation_1-rmse:0.00130
# [161]	validation_0-rmse:0.00126	validation_1-rmse:0.00129
# [162]	validation_0-rmse:0.00125	validation_1-rmse:0.00128
# [163]	validation_0-rmse:0.00124	validation_1-rmse:0.00127
# [164]	validation_0-rmse:0.00123	validation_1-rmse:0.00125
# [165]	validation_0-rmse:0.00121	validation_1-rmse:0.00124
# [166]	validation_0-rmse:0.00120	validation_1-rmse:0.00123
# [167]	validation_0-rmse:0.00119	validation_1-rmse:0.00122
# [168]	validation_0-rmse:0.00118	validation_1-rmse:0.00120
# [169]	validation_0-rmse:0.00117	validation_1-rmse:0.00119
# 최종 Mean Squared Error: 0.00
# 최종 R2 Score: 0.97
# ['./xgboost_incheon_model.pkl']

# %%
y_pred = xgb_model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'MSE: {mse}, R2: {r2}')
# Out:
# MSE: 1.4197953417105671e-06, R2: 0.9667050442702357

# %%
xgb_model = joblib.load('./xgboost_incheon_model.pkl')

scaler = StandardScaler()
scaler.fit(X_train)  
input_data = {
    '진료과목_인코딩': [7],  
    '지역_인코딩': [10],         # 고정값
    '의료기관_인코딩': [1], 
    '최종수가_표준화': [0.8],  
    'K-MEAN 군집': [3], 
    '인천광역시 건강보험_표준화': [0],
    '의료수가_표준화': [1],
    "인천광역시_소아과 병원 수_표준화" :[0.5],
    "인천광역시_소아과 의료인력 수_표준화" :[0.2],
    "인천광역시_소아과 병원 수":[650]
}
input_df = pd.DataFrame(input_data)

input_scaled = scaler.transform(input_df)

prediction_1 = xgb_model.predict(input_scaled)
print(f'예측 결과: {prediction_1[0]} (표준화된 소아과 병원 수)')
# Out:
# 예측 결과: 0.1866207718849182 (표준화된 소아과 병원 수)
