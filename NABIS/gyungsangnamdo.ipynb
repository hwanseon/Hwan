# %%
from sklearn.datasets import make_moons
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
from sklearn.impute import KNNImputer
import pandas as pd
import matplotlib.pyplot as plt
import koreanize_matplotlib
from tabulate import tabulate 
import glob

from sklearn.preprocessing import LabelEncoder
import seaborn as sns

from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.metrics import mean_squared_error, r2_score
import joblib

# %%
NABIS = pd.read_csv("./진짜 진짜 진짜로 전처리 완료된 대회 분석 데이터.csv")
NABIS = pd.DataFrame(NABIS)
NABIS
# Out:
#       Unnamed: 0    연도    의료수가   가중치  지역 소아과 수        최종수가  강원특별자치도_건강보험  \
# 0              0  2019  258854  74.9       864  19388164.6       1491120
# 1              1  2019  258854  83.4       864  21588423.6       1491120
# 2              2  2019  258854  74.9     10940  19388164.6       1491120
# 3              3  2019  258854  83.4     10940  21588423.6       1491120
# 4              4  2019  258854  74.9      8032  19388164.6       1491120
# ...          ...   ...     ...   ...       ...         ...           ...
# 1787        1787  2022  617545  78.4      8032  48415528.0       1503671
# 1788        1788  2022  617545  78.4       996  48415528.0       1503671
# 1789        1789  2022  617545  90.2       996  55702559.0       1503671
# 1790        1790  2022  617545  78.4       816  48415528.0       1503671
# 1791        1791  2022  617545  90.2       816  55702559.0       1503671
#
#       강원특별자치도_소아과 병원 수  강원특별자치도_소아과 의료인력 수  강원특별자치도_천명당 소아과 수  ...  \
# 0                  864                 527           0.142105  ...
# 1                  864                 527           0.142105  ...
# 2                  864                 527           0.142105  ...
# 3                  864                 527           0.142105  ...
# 4                  864                 527           0.142105  ...
# ...                ...                 ...                ...  ...
# 1787               904                 618           0.148003  ...
# 1788               904                 618           0.148003  ...
# 1789               904                 618           0.148003  ...
# 1790               904                 618           0.148003  ...
# 1791               904                 618           0.148003  ...
#
#       전북특별자치도_소아과 병원 수_표준화  전북특별자치도_소아과 의료인력 수_표준화  전라남도_소아과 병원 수_표준화  \
# 0                 1.532478               -0.463988           1.310556
# 1                 1.532478               -0.463988           1.310556
# 2                 1.532478               -0.463988           1.310556
# 3                 1.532478               -0.463988           1.310556
# 4                 1.532478               -0.463988           1.310556
# ...                    ...                     ...                ...
# 1787             -0.998219                1.716757          -0.087370
# 1788             -0.998219                1.716757          -0.087370
# 1789             -0.998219                1.716757          -0.087370
# 1790             -0.998219                1.716757          -0.087370
# 1791             -0.998219                1.716757          -0.087370
#
#       전라남도_소아과 의료인력 수_표준화  경상북도_소아과 병원 수_표준화  경상북도_소아과 의료인력 수_표준화  \
# 0                0.110959           0.848528             1.163333
# 1                0.110959           0.848528             1.163333
# 2                0.110959           0.848528             1.163333
# 3                0.110959           0.848528             1.163333
# 4                0.110959           0.848528             1.163333
# ...                   ...                ...                  ...
# 1787            -0.776713          -0.848528            -1.398134
# 1788            -0.776713          -0.848528            -1.398134
# 1789            -0.776713          -0.848528            -1.398134
# 1790            -0.776713          -0.848528            -1.398134
# 1791            -0.776713          -0.848528            -1.398134
#
#       경상남도_소아과 병원 수_표준화  경상남도_소아과 의료인력 수_표준화  제주특별자치도_소아과 병원 수_표준화  \
# 0              1.427416            -1.091442             -1.647064
# 1              1.427416            -1.091442             -1.647064
# 2              1.427416            -1.091442             -1.647064
# 3              1.427416            -1.091442             -1.647064
# 4              1.427416            -1.091442             -1.647064
# ...                 ...                  ...                   ...
# 1787          -0.965205             1.570042              0.930949
# 1788          -0.965205             1.570042              0.930949
# 1789          -0.965205             1.570042              0.930949
# 1790          -0.965205             1.570042              0.930949
# 1791          -0.965205             1.570042              0.930949
#
#       제주특별자치도_소아과 의료인력 수_표준화
# 0                  -1.598822
# 1                  -1.598822
# 2                  -1.598822
# 3                  -1.598822
# 4                  -1.598822
# ...                      ...
# 1787                1.157767
# 1788                1.157767
# 1789                1.157767
# 1790                1.157767
# 1791                1.157767
#
# [1792 rows x 121 columns]

# %%
from sklearn.cluster import KMeans

features = NABIS[['진료과목_인코딩', '지역_인코딩', '의료기관_인코딩', '최종수가_표준화', '지역 소아과 수', 
    '경상남도_건강보험', '경상남도_소아과 병원 수_표준화', "경상남도_소아과 의료인력 수_표준화", "경상남도_천명당 소아과 수"]]

# n_clusters: 군집 개수를 설정 
n_clusters = 40
kmeans = KMeans(n_clusters=n_clusters, random_state=43)

NABIS['K-MEAN 군집'] = kmeans.fit_predict(features)

KGoonjib = './K-MEAN 경상남도 군집화 결과2.xlsx'
NABIS.to_excel(KGoonjib, index=False)

NABIS['K-MEAN 군집'].value_counts()
# Out:
# K-MEAN 군집
# 5     168
# 2     168
# 7     168
# 6     168
# 23     56
# 30     56
# 14     56
# 28     56
# 1      28
# 8      28
# 19     28
# 0      28
# 25     28
# 24     28
# 12     28
# 38     28
# 16     28
# 4      28
# 17     28
# 32     28
# 29     28
# 35     28
# 37     28
# 10     28
# 3      28
# 33     28
# 18     28
# 13     28
# 22     28
# 27     28
# 36     28
# 11     28
# 9      28
# 34     28
# 20     28
# 15     28
# 21     28
# 26     28
# 39     28
# 31     28
# Name: count, dtype: int64

# %%
# Elbow 방법으로 SSE(군집내 제곱합)을 계산하여 최적의 군집 수 찾기
sse = []  
k_range = range(1, 40)  

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=43)
    kmeans.fit(features)
    sse.append(kmeans.inertia_)  

plt.figure(figsize=(10, 6))
plt.plot(k_range, sse, marker='o')
plt.xlabel('K')
plt.ylabel('SSE')
plt.title('Elbow의 최적의 군집 수')
plt.xticks(k_range)
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import silhouette_score

# 실루엣 계수로 최적의 군집 수 찾기
silhouette_scores = []
k_range = range(2, 50)  

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=43)
    cluster_labels = kmeans.fit_predict(features)
    silhouette_avg = silhouette_score(features, cluster_labels)
    silhouette_scores.append(silhouette_avg)

plt.figure(figsize=(10, 6))
plt.plot(k_range, silhouette_scores, marker='o')
plt.xlabel('k')
plt.ylabel('실루엣 스코어')
plt.title('Silhouette Score의 최적의 군집 수')
plt.xticks(k_range)
plt.grid(True)
plt.show()

# %%
# k-mean 군집화 분석 

Kcluster_counts = NABIS['K-MEAN 군집'].value_counts()
print("\n군집별 데이터 수:\n", Kcluster_counts)

Kcluster_means = NABIS.groupby('K-MEAN 군집').mean()
print("\n군집별 평균값:\n", Kcluster_means)

plt.figure(figsize=(10, 6))
sns.boxplot(x='K-MEAN 군집', y='최종수가_표준화', data=NABIS)
plt.title('군집별 최종수가_표준화 분포')
plt.xlabel('군집')
plt.ylabel('최종수가_표준화')
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x='K-MEAN 군집', y='지역 소아과 수', data=NABIS)
plt.title('군집별 지역 소아과 수 분포')
plt.xlabel('군집')
plt.ylabel('지역 소아과 수')
plt.grid(True)
plt.show()
# Out:
# 군집별 데이터 수:
#  K-MEAN 군집
# 5     168
# 2     168
# 7     168
# 6     168
# 23     56
# 30     56
# 14     56
# 28     56
# 1      28
# 8      28
# 19     28
# 0      28
# 25     28
# 24     28
# 12     28
# 38     28
# 16     28
# 4      28
# 17     28
# 32     28
# 29     28
원특별자치도_소아과 병원 수  강원특별자치도_소아과 의료인력 수  \
# K-MEAN 군집
# 0          1.205247e+08     1499980.0             876.0               580.0
# 1          1.173609e+08     1491120.0             864.0               527.0
# 2          1.159702e+08     1503671.0             904.0               618.0
# 3          1.185983e+08     1494407.0             904.0               537.0
# 4          1.231529e+08     1503671.0             904.0               618.0
# 5          1.121094e+08     1491120.0             864.0               527.0
# 6          1.127416e+08     1494407.0             904.0               537.0
# 7          1.142512e+08     1499980.0             876.0               580.0
# 8          1.205247e+08     1499980.0             876.0               580.0
# 9          1.173609e+08     1491120.0             864.0               527.0
# 10         1.205247e+08     1499980.0             876.0               580.0
# 11         1.185983e+08     1494407.0             904.0               537.0
# 12         1.231529e+08     1503671.0             904.0               618.0
# 13         1.173609e+08     1491120.0             864.0               527.0
# 14         1.231529e+08     1503671.0             904.0               618.0
# 15         1.185983e+08     1494407.0             904.0               537.0
# 16         1.231529e+08     1503671.0             904.0               618.0
# 17         1.231529e+08     1503671.0             904.0               618.0
# 18         1.173609e+08     1491120.0             864.0               527.0
# 19         1.205247e+08     1499980.0             876.0               580.0
# 20         1.185983e+08     1494407.0             904.0               537.0
# 21         1.185983e+08     1494407.0             904.0               537.0
# 22         1.173609e+08     1491120.0             864.0               527.0
# 23         1.205247e+08     1499980.0             876.0               580.0
# 24         1.205247e+08     1499980.0             876.0               580.0
# 25         1.205247e+08     1499980.0             876.0               580.0
# 26         1.185983e+08     1494407.0             904.0               537.0
# 27         1.173609e+08     1491120.0             864.0               527.0
# 28         1.185983e+08     1494407.0             904.0               537.0
# 29         1.231529e+08     1503671.0             904.0               618.0
# 30         1.173609e+08     1491120.0             864.0               527.0
# 31         1.231529e+08     1503671.0             904.0               618.0
# 32         1.231529e+08     1503671.0             904.0               618.0
# 33         1.173609e+08     1491120.0             864.0               527.0
# 34         1.185983e+08     1494407.0             904.0               537.0
# 35         1.205247e+08     1499980.0             876.0               580.0
# 36         1.173609e+08     1491120.0             864.0               527.0
# 37         1.205247e+08     1499980.0             876.0               580.0
# 38         1.231529e+08     1503671.0             904.0               618.0
# 39         1.185983e+08     1494407.0             904.0               537.0
#
#            강원특별자치도_천명당 소아과 수  ...  전북특별자치도_소아과 병원 수_표준화  \
# K-MEAN 군집                     ...
# 0                   0.144079  ...             -0.773269
# 1                   0.142105  ...              1.532478
# 2                   0.148003  ...             -0.998219
# 3                   0.148782  ...              0.239010
# 4                   0.148003  ...             -0.998219
# 5                   0.142105  ...              1.532478
# 6                   0.148782  ...              0.239010
# 7                   0.144079  ...             -0.773269
# 8                   0.144079  ...             -0.773269
# 9                   0.142105  ...              1.532478
# 10                  0.144079  ...             -0.773269
# 11                  0.148782  ...              0.239010
# 12                  0.148003  ...             -0.998219
# 13                  0.142105  ...              1.532478
# 14                  0.148003  ...             -0.998219
# 15                  0.148782  ...              0.239010
# 16                  0.148003  ...             -0.998219
# 17                  0.148003  ...             -0.998219
# 33                   -1.091442             -1.647064               -1.598822
# 34                   -0.577822              0.071611                0.165395
# 35                    0.099222              0.644503                0.275659
# 36                   -1.091442             -1.647064               -1.598822
# 37                    0.099222              0.644503                0.275659
# 38                    1.570042              0.930949                1.157767
# 39                   -0.577822              0.071611                0.165395
#
# [40 rows x 121 columns]

# %%
# PCA
from sklearn.decomposition import PCA
NABIS1 = NABIS.copy()

# 2차원 축소
pca = PCA(n_components=2)
pca_result = pca.fit_transform(features)

NABIS1['PCA1'] = pca_result[:, 0]
NABIS1['PCA2'] = pca_result[:, 1]

plt.figure(figsize=(12, 8))
sns.scatterplot(x='PCA1', y='PCA2', hue='K-MEAN 군집', palette='Set1', data=NABIS1, s=50, alpha=0.7, edgecolor='k')
plt.title('주성분 분석')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.legend(title='Cluster')
plt.grid(True)
plt.show()

# %%
NABIS.columns
# Out:
# Index(['Unnamed: 0', '연도', '의료수가', '가중치', '지역 소아과 수', '최종수가', '강원특별자치도_건강보험',
#        '강원특별자치도_소아과 병원 수', '강원특별자치도_소아과 의료인력 수', '강원특별자치도_천명당 소아과 수',
#        ...
#        '전북특별자치도_소아과 의료인력 수_표준화', '전라남도_소아과 병원 수_표준화', '전라남도_소아과 의료인력 수_표준화',
#        '경상북도_소아과 병원 수_표준화', '경상북도_소아과 의료인력 수_표준화', '경상남도_소아과 병원 수_표준화',
#        '경상남도_소아과 의료인력 수_표준화', '제주특별자치도_소아과 병원 수_표준화', '제주특별자치도_소아과 의료인력 수_표준화',
#        'K-MEAN 군집'],
#       dtype='object', length=122)

# %%
X = NABIS[['진료과목_인코딩', '지역_인코딩', '의료기관_인코딩', '최종수가_표준화', 'K-MEAN 군집', '경상남도 건강보험_표준화', '의료수가_표준화', "경상남도_소아과 병원 수_표준화",
           "경상남도_소아과 의료인력 수_표준화"]]
y = NABIS['경상남도_천명당 소아과 수']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=43)

xgb_model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=170, learning_rate=0.01, max_depth=7, random_state=43)

# 모델 학습
xgb_model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_test, y_test)], verbose=True)

evals_result = xgb_model.evals_result()
train_loss = evals_result['validation_0']['rmse']
test_loss = evals_result['validation_1']['rmse']

train_r2_scores = []
test_r2_scores = []

for i in range(len(train_loss)):
    y_train_pred = xgb_model.predict(X_train, iteration_range=(0, i + 1))
    y_test_pred = xgb_model.predict(X_test, iteration_range=(0, i + 1))
    
    train_r2 = r2_score(y_train, y_train_pred)
    test_r2 = r2_score(y_test, y_test_pred)
    train_r2_scores.append(train_r2)
    test_r2_scores.append(test_r2)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Train Loss (RMSE)')
plt.plot(test_loss, label='Test Loss (RMSE)')
plt.xlabel('학습횟수')
plt.ylabel('RMSE')
plt.title('Train and Test Loss')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(train_r2_scores, label='Train R2 Score')
plt.plot(test_r2_scores, label='Test R2 Score')
plt.xlabel('학습횟수')
plt.ylabel('R2 Score')
plt.title('Train and Test R2 Score')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

y_pred = xgb_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"\n최종 Mean Squared Error: {mse:.2f}")
print(f"최종 R2 Score: {r2:.2f}")

# 모델 저장 
joblib.dump(xgb_model, './xgboost_gyungsangnamdo_model.pkl')
# Out:
# [0]	validation_0-rmse:0.00470	validation_1-rmse:0.00479
# [1]	validation_0-rmse:0.00466	validation_1-rmse:0.00474
# [2]	validation_0-rmse:0.00461	validation_1-rmse:0.00469
# [3]	validation_0-rmse:0.00457	validation_1-rmse:0.00465
# [4]	validation_0-rmse:0.00452	validation_1-rmse:0.00460
# [5]	validation_0-rmse:0.00447	validation_1-rmse:0.00456
# [6]	validation_0-rmse:0.00443	validation_1-rmse:0.00451
# [7]	validation_0-rmse:0.00439	validation_1-rmse:0.00446
# [52]	validation_0-rmse:0.00279	validation_1-rmse:0.00284
# [53]	validation_0-rmse:0.00277	validation_1-rmse:0.00282
# [54]	validation_0-rmse:0.00274	validation_1-rmse:0.00279
# [55]	validation_0-rmse:0.00271	validation_1-rmse:0.00276
# [56]	validation_0-rmse:0.00268	validation_1-rmse:0.00273
# [57]	validation_0-rmse:0.00266	validation_1-rmse:0.00271
# [58]	validation_0-rmse:0.00263	validation_1-rmse:0.00268
# [59]	validation_0-rmse:0.00260	validation_1-rmse:0.00265
# [60]	validation_0-rmse:0.00258	validation_1-rmse:0.00262
# [61]	validation_0-rmse:0.00255	validation_1-rmse:0.00260
# [62]	validation_0-rmse:0.00253	validation_1-rmse:0.00257
# [63]	validation_0-rmse:0.00250	validation_1-rmse:0.00255
# [64]	validation_0-rmse:0.00248	validation_1-rmse:0.00252
# [65]	validation_0-rmse:0.00245	validation_1-rmse:0.00250
# [66]	validation_0-rmse:0.00243	validation_1-rmse:0.00247
# [67]	validation_0-rmse:0.00240	validation_1-rmse:0.00245
# [68]	validation_0-rmse:0.00238	validation_1-rmse:0.00242
# [69]	validation_0-rmse:0.00236	validation_1-rmse:0.00240
# [70]	validation_0-rmse:0.00233	validation_1-rmse:0.00237
# [71]	validation_0-rmse:0.00231	validation_1-rmse:0.00235
# [72]	validation_0-rmse:0.00229	validation_1-rmse:0.00233
# [73]	validation_0-rmse:0.00226	validation_1-rmse:0.00230
# [74]	validation_0-rmse:0.00224	validation_1-rmse:0.00228
# [75]	validation_0-rmse:0.00222	validation_1-rmse:0.00226
# [76]	validation_0-rmse:0.00220	validation_1-rmse:0.00224
# [77]	validation_0-rmse:0.00217	validation_1-rmse:0.00221
# [78]	validation_0-rmse:0.00215	validation_1-rmse:0.00219
# [79]	validation_0-rmse:0.00213	validation_1-rmse:0.00217
# [80]	validation_0-rmse:0.00211	validation_1-rmse:0.00215
# [81]	validation_0-rmse:0.00209	validation_1-rmse:0.00213
# [82]	validation_0-rmse:0.00207	validation_1-rmse:0.00211
# [83]	validation_0-rmse:0.00205	validation_1-rmse:0.00208
# [84]	validation_0-rmse:0.00203	validation_1-rmse:0.00206
# [85]	validation_0-rmse:0.00201	validation_1-rmse:0.00204
# [86]	validation_0-rmse:0.00199	validation_1-rmse:0.00202
# [87]	validation_0-rmse:0.00197	validation_1-rmse:0.00200
# [88]	validation_0-rmse:0.00195	validation_1-rmse:0.00198
# [89]	validation_0-rmse:0.00193	validation_1-rmse:0.00196
# [90]	validation_0-rmse:0.00191	validation_1-rmse:0.00194
# [91]	validation_0-rmse:0.00189	validation_1-rmse:0.00192
# [92]	validation_0-rmse:0.00187	validation_1-rmse:0.00190
# [93]	validation_0-rmse:0.00185	validation_1-rmse:0.00189
# [94]	validation_0-rmse:0.00183	validation_1-rmse:0.00187
# [95]	validation_0-rmse:0.00182	validation_1-rmse:0.00185
# [96]	validation_0-rmse:0.00180	validation_1-rmse:0.00183
# [97]	validation_0-rmse:0.00178	validation_1-rmse:0.00181
# [98]	validation_0-rmse:0.00176	validation_1-rmse:0.00179
# [99]	validation_0-rmse:0.00174	validation_1-rmse:0.00178
# [100]	validation_0-rmse:0.00173	validation_1-rmse:0.00176
# [101]	validation_0-rmse:0.00171	validation_1-rmse:0.00174
# [102]	validation_0-rmse:0.00169	validation_1-rmse:0.00172
# [103]	validation_0-rmse:0.00168	validation_1-rmse:0.00171
# [104]	validation_0-rmse:0.00166	validation_1-rmse:0.00169
# [105]	validation_0-rmse:0.00164	validation_1-rmse:0.00167
# [106]	validation_0-rmse:0.00163	validation_1-rmse:0.00166
# [107]	validation_0-rmse:0.00161	validation_1-rmse:0.00164
# [108]	validation_0-rmse:0.00159	validation_1-rmse:0.00162
# [109]	validation_0-rmse:0.00158	validation_1-rmse:0.00161
# [110]	validation_0-rmse:0.00156	validation_1-rmse:0.00159
# [111]	validation_0-rmse:0.00155	validation_1-rmse:0.00157
# [112]	validation_0-rmse:0.00153	validation_1-rmse:0.00156
# [113]	validation_0-rmse:0.00152	validation_1-rmse:0.00154
# [114]	validation_0-rmse:0.00150	validation_1-rmse:0.00153
# [115]	validation_0-rmse:0.00149	validation_1-rmse:0.00151
# [116]	validation_0-rmse:0.00147	validation_1-rmse:0.00150
# [117]	validation_0-rmse:0.00146	validation_1-rmse:0.00148
# [118]	validation_0-rmse:0.00144	validation_1-rmse:0.00147
# [119]	validation_0-rmse:0.00143	validation_1-rmse:0.00145
# [120]	validation_0-rmse:0.00141	validation_1-rmse:0.00144
# [121]	validation_0-rmse:0.00140	validation_1-rmse:0.00142
# [122]	validation_0-rmse:0.00139	validation_1-rmse:0.00141
# [123]	validation_0-rmse:0.00137	validation_1-rmse:0.00140
# [124]	validation_0-rmse:0.00136	validation_1-rmse:0.00138
# [125]	validation_0-rmse:0.00134	validation_1-rmse:0.00137
# [126]	validation_0-rmse:0.00133	validation_1-rmse:0.00135
# [127]	validation_0-rmse:0.00132	validation_1-rmse:0.00134
# [128]	validation_0-rmse:0.00130	validation_1-rmse:0.00133
# [129]	validation_0-rmse:0.00129	validation_1-rmse:0.00131
# [130]	validation_0-rmse:0.00128	validation_1-rmse:0.00130
# [131]	validation_0-rmse:0.00127	validation_1-rmse:0.00129
# [132]	validation_0-rmse:0.00125	validation_1-rmse:0.00128
# [133]	validation_0-rmse:0.00124	validation_1-rmse:0.00126
# [134]	validation_0-rmse:0.00123	validation_1-rmse:0.00125
# [135]	validation_0-rmse:0.00122	validation_1-rmse:0.00124
# [136]	validation_0-rmse:0.00120	validation_1-rmse:0.00123
# [137]	validation_0-rmse:0.00119	validation_1-rmse:0.00121
# [138]	validation_0-rmse:0.00118	validation_1-rmse:0.00120
# [139]	validation_0-rmse:0.00117	validation_1-rmse:0.00119
# [140]	validation_0-rmse:0.00116	validation_1-rmse:0.00118
# [141]	validation_0-rmse:0.00115	validation_1-rmse:0.00117
# [142]	validation_0-rmse:0.00113	validation_1-rmse:0.00115
# [143]	validation_0-rmse:0.00112	validation_1-rmse:0.00114
# [144]	validation_0-rmse:0.00111	validation_1-rmse:0.00113
# [145]	validation_0-rmse:0.00110	validation_1-rmse:0.00112
# [146]	validation_0-rmse:0.00109	validation_1-rmse:0.00111
# [147]	validation_0-rmse:0.00108	validation_1-rmse:0.00110
# [148]	validation_0-rmse:0.00107	validation_1-rmse:0.00109
# [149]	validation_0-rmse:0.00106	validation_1-rmse:0.00108
# [150]	validation_0-rmse:0.00105	validation_1-rmse:0.00107
# [151]	validation_0-rmse:0.00104	validation_1-rmse:0.00105
# [152]	validation_0-rmse:0.00103	validation_1-rmse:0.00104
# [153]	validation_0-rmse:0.00102	validation_1-rmse:0.00103
# [154]	validation_0-rmse:0.00101	validation_1-rmse:0.00102
# [155]	validation_0-rmse:0.00100	validation_1-rmse:0.00101
# [156]	validation_0-rmse:0.00099	validation_1-rmse:0.00100
# [157]	validation_0-rmse:0.00098	validation_1-rmse:0.00099
# [158]	validation_0-rmse:0.00097	validation_1-rmse:0.00098
# [159]	validation_0-rmse:0.00096	validation_1-rmse:0.00097
# [160]	validation_0-rmse:0.00095	validation_1-rmse:0.00096
# [161]	validation_0-rmse:0.00094	validation_1-rmse:0.00095
# [162]	validation_0-rmse:0.00093	validation_1-rmse:0.00094
# [163]	validation_0-rmse:0.00092	validation_1-rmse:0.00093
# [164]	validation_0-rmse:0.00091	validation_1-rmse:0.00093
# [165]	validation_0-rmse:0.00090	validation_1-rmse:0.00092
# [166]	validation_0-rmse:0.00089	validation_1-rmse:0.00091
# [167]	validation_0-rmse:0.00088	validation_1-rmse:0.00090
# [168]	validation_0-rmse:0.00087	validation_1-rmse:0.00089
# [169]	validation_0-rmse:0.00086	validation_1-rmse:0.00088
# 최종 Mean Squared Error: 0.00
# 최종 R2 Score: 0.97
# ['./xgboost_gyungsangnamdo_model.pkl']

# %%
y_pred = xgb_model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'MSE: {mse}, R2: {r2}')
# Out:
# MSE: 7.75135208671291e-07, R2: 0.9667313938779506

# %%
xgb_model = joblib.load('./xgboost_gyungsangnamdo_model.pkl')

scaler = StandardScaler()
scaler.fit(X_train)  

input_data = {
    '진료과목_인코딩': [7],  
    '지역_인코딩': [2],         # 고정값
    '의료기관_인코딩': [0], 
    '최종수가_표준화': [-0.65],  
    'K-MEAN 군집': [38], 
    '경상남도 건강보험_표준화': [1.577019],
    '의료수가_표준화': [-0.471806],
    "경상남도_소아과 병원 수_표준화" :[800],
    "경상남도_소아과 의료인력 수_표준화" :[0.2]
}
input_df = pd.DataFrame(input_data)

input_scaled = scaler.transform(input_df)

prediction_1 = xgb_model.predict(input_scaled)
print(f'예측 결과: {prediction_1[0]} (표준화된 소아과 병원 수)')
# Out:
# 예측 결과: 0.12171189486980438 (표준화된 소아과 병원 수)
